# %%
import numpy as np
import pandas as pd
import torch 
import torchvision
import transformers 
import datetime as dt

# %%
data = pd.read_csv('~/Downloads/MyCourses/StockMarketSentimentAnalysis/AMZN_prerob.csv')

# %%
data.head()
# Out:
#   Publishing Time Ticker Sector Source Headline Text  URL fin_sentiment  \
# 0             NaN    NaN    NaN    NaN      NaN  NaN  NaN           NaN
# 1             NaN    NaN    NaN    NaN      NaN  NaN  NaN           NaN
# 2             NaN    NaN    NaN    NaN      NaN  NaN  NaN           NaN
# 3             NaN    NaN    NaN    NaN      NaN  NaN  NaN           NaN
# 4             NaN    NaN    NaN    NaN      NaN  NaN  NaN           NaN
#
#    finvader_tot rob_sentiment  rob_score                 stock_time     open  \
# 0           NaN           NaN        NaN  2019-03-15 08:00:00+00:00  1706.00
# 1           NaN           NaN        NaN  2019-03-15 08:15:00+00:00  1708.67
# 2           NaN           NaN        NaN  2019-03-15 09:00:00+00:00  1709.24
# 3           NaN           NaN        NaN  2019-03-15 09:15:00+00:00  1708.00
# 4           NaN           NaN        NaN  2019-03-15 09:30:00+00:00  1708.00
#
#       high      low    close  volume  numtrades         vwap
# 0  1711.00  1706.00  1711.00    1497         61  1707.697582
# 1  1708.67  1708.67  1708.67     230          4  1708.561217
# 2  1709.24  1709.11  1709.11     605          7  1709.173884
# 3  1708.00  1708.00  1708.00     200          1  1708.000000
# 4  1708.00  1707.98  1707.98     201          3  1707.987413

# %%
data.columns
# Out:
# Index(['Publishing Time', 'Ticker', 'Sector', 'Source', 'Headline', 'Text',
#        'URL', 'fin_sentiment', 'finvader_tot', 'rob_sentiment', 'rob_score',
#        'stock_time', 'open', 'high', 'low', 'close', 'volume', 'numtrades',
#        'vwap'],
#       dtype='object')

# %%
# Converting the stock_times into datetime objects
data['stock_time'] = pd.to_datetime(data['stock_time'])

# %%
# extracting indices of times immediately after a news article was published
publishing_indices = data[data['Publishing Time'].notna()].index

# %%
averages = []
for i in range(len(publishing_indices) + 1):
    if i == 0:
        start, end = 0 , publishing_indices[0]
    elif i == len(publishing_indices):
        start, end = publishing_indices[-1], len(data) - 1
    else:
        start, end = publishing_indices[i - 1], publishing_indices[i]
#     print(f'start is {start} end is {end}')
    averages.append(data['open'][start:end].mean())

# %%
len(publishing_indices)
# Out:
# 14028

# %%
len(averages)
# Out:
# 14029

# %%
unique_sentiments = data['rob_sentiment'][data['rob_sentiment'].notna()].unique()

# %%
unique_sentiments
# Out:
# array(['positive', 'neutral', 'negative'], dtype=object)

# %%
rob_sentiment = data['rob_sentiment'][data['rob_sentiment'].notna()]
rob_sentiment = list(rob_sentiment)

# %%
matching_with_sentiment = []
for i in range(1 , len(averages)-1):
    diff = averages[i] - averages[i - 1]
    if (diff > 0 and rob_sentiment[i] == 'positive') or (diff < 0 and rob_sentiment[i] == 'negative'):
        matching_with_sentiment.append([True , i , diff , rob_sentiment[i]])
    elif rob_sentiment[i] == 'neutral':
        continue
    else:
        matching_with_sentiment.append([False , i , diff , rob_sentiment[i]])

matching_with_sentiment
# Out:
# [[False, 1, -2.24048461538473, 'positive'],
#  [True, 2, 5.295857142857358, 'positive'],
#  [False, 4, -2.8864999999998417, 'positive'],
#  [False, 5, -7.229000000000042, 'positive'],
#  [True, 6, 4.186388888888814, 'positive'],
#  [True, 7, 3.2386111111111404, 'positive'],
#  [True, 10, 15.861825806451634, 'positive'],
#  [True, 11, 16.39521705069137, 'positive'],
#  [True, 12, -3.9820428571429147, 'negative'],
#  [True, 16, -2.32204999999999, 'negative'],
#  [False, 18, -7.677379679144224, 'positive'],
#  [True, 20, 3.2228333333330283, 'positive'],
#  [True, 23, 2.3200000000001637, 'positive'],
#  [True, 24, 4.95844444444424, 'positive'],
#  [True, 26, 2.3102957142855303, 'positive'],
#  [True, 27, -4.572063492063307, 'negative'],
#  [True, 29, 3.6520799999998417, 'positive'],
#  [True, 30, 15.003474761904727, 'positive'],
#  [False, 31, -7.7426297619049365, 'positive'],
#  [False, 32, -6.249991666666347, 'positive'],
#  [True, 33, -10.006233333333284, 'negative'],
#  [False, 34, -11.440000000000055, 'positive'],
#  [True, 35, 3.9899999999995543, 'positive'],
#  [True, 38, 9.691936842105406, 'positive'],
#  [True, 40, 6.332562500000222, 'positive'],
#  [True, 41, 17.43648392857108, 'positive'],
#  [False, 42, -3.8013947981362435, 'positive'],
#  [False, 43, -21.05434396914461, 'positive'],
#  [True, 46, 8.199898666666968, 'positive'],
#  [False, 50, 0.0, 'positive'],
#  [False, 51, 0.0, 'positive'],
#  [False, 52, -2.986666666666679, 'positive'],
#  [True, 54, 2.160298412698239, 'positive'],
#  [True, 55, 2.868590476190775, 'positive'],
#  [True, 56, 5.285021212121364, 'positive'],
#  [False, 58, -0.27749999999991815, 'positive'],
#  [True, 59, 1.2200000000000273, 'positive'],
#  [False, 62, -1.1700000000000728, 'positive'],
#  [False, 63, -2.7940000000000964, 'positive'],
#  [False, 64, 3.3756750000002285, 'negative'],
#  [False, 65, -1.1966750000001412, 'positive'],
#  [True, 66, 1.02800000000002, 'positive'],
#  [False, 68, -0.8638699999999062, 'positive'],
#  [True, 69, 10.138000000000147, 'positive'],
#  [True, 71, 0.6266666666665515, 'positive'],
#  [False, 73, 0.0, 'positive'],
#  [True, 74, 0.7099000000000615, 'positive'],
#  [False, 76, 1.71273846153872, 'negative'],
#  [False, 77, -7.256026470588267, 'positive'],
#  [False, 79, -2.2316666666663423, 'positive'],
#  [False, 83, -0.8664999999998599, 'positive'],
#  [False, 84, 1.2129999999999654, 'negative'],
#  [True, 88, 2.5550000000000637, 'positive'],
#  [True, 89, 2.3416666666664696, 'positive'],
#  [True, 90, 3.5770833333333485, 'positive'],
#  [False, 92, 0.5201700000000073, 'negative'],
#  [False, 94, 2.445871428571536, 'negative'],
#  [True, 95, 3.1096999999999753, 'positive'],
#  [False, 102, -4.396173333333309, 'positive'],
#  [True, 104, 9.075975000000426, 'positive'],
#  [True, 106, 2.9149999999999636, 'positive'],
#  [False, 108, -2.735728205127998, 'positive'],
#  [True, 110, -7.371121739130558, 'negative'],
#  [False, 111, -0.5388888888890051, 'positive'],
#  [True, 113, 1.662000000000262, 'positive'],
#  [False, 115, -2.309422222222338, 'positive'],
#  [False, 119, -2.7109999999997854, 'positive'],
#  [True, 121, 1.0299999999999727, 'positive'],
#  [False, 124, 0.5499999999999545, 'negative'],
#  [True, 128, 1.632499999999709, 'positive'],
#  [True, 130, -0.5977333333335082, 'negative'],
#  [True, 134, 5.518000000000029, 'positive'],
#  [True, 135, 2.7587499999999636, 'positive'],
#  [True, 136, 1.0051071428572413, 'positive'],
#  [True, 137, 1.136142857142886, 'positive'],
#  [False, 139, -0.7599999999999909, 'positive'],
#  [False, 145, 2.5700000000001637, 'negative'],
#  [False, 146, 0.0, 'negative'],
#  [False, 148, 0.0, 'positive'],
#  [False, 149, 0.0, 'positive'],
#  [False, 150, 0.0, 'negative'],
#  [False, 152, -2.7480833333331702, 'positive'],
#  [False, 162, -1.4766666666666879, 'positive'],
#  [True, 163, 8.828560000000152, 'positive'],
#  [True, 164, -1.7384985964911266, 'negative'],
#  [True, 165, -4.838019736842398, 'negative'],
#  [False, 166, -0.24037499999963075, 'positive'],
#  [True, 167, -0.27833333333342125, 'negative'],
#  [False, 169, 2.79982121212106, 'negative'],
#  [False, 172, -3.153830769230808, 'positive'],
#  [False, 173, 0.0, 'positive'],
#  [False, 174, 0.0, 'positive'],
#  [False, 176, -2.598830769230517, 'positive'],
#  [True, 177, 21.84606201923043, 'positive'],
#  [False, 178, 7.108140178571375, 'negative'],
#  [True, 179, 4.522136904762419, 'positive'],
#  [True, 180, -1.9246511904768795, 'negative'],
#  [False, 182, -0.005000000000109139, 'positive'],
#  [True, 183, 4.6357874999998785, 'positive'],
#  [True, 184, 13.409212500000194, 'positive'],
#  [True, 185, 5.356133333333446, 'positive'],
#  [False, 190, -7.357300000000123, 'positive'],
#  [False, 192, -5.007341666666662, 'positive'],
#  [True, 193, 4.366666666666788, 'positive'],
#  [True, 194, -0.15000000000009095, 'negative'],
#  [False, 196, 5.308987999999999, 'negative'],
#  [True, 198, 2.2412541666667494, 'positive'],
#  [True, 199, -5.4301208333336035, 'negative'],
#  [True, 201, 0.8300285714281017, 'positive'],
#  [False, 203, -4.638416666666444, 'positive'],
#  [False, 204, -4.616583333333438, 'positive'],
#  [False, 205, 0.0, 'positive'],
#  [False, 206, 15.450000000000045, 'negative'],
#  [False, 208, 0.0, 'negative'],
#  [True, 209, 0.3366666666668152, 'positive'],
#  [True, 210, -20.736666666666906, 'negative'],
#  [True, 211, 2.910000000000082, 'positive'],
#  [True, 212, 14.6400000000001, 'positive'],
#  [False, 213, 0.0, 'negative'],
#  [False, 215, 0.0, 'positive'],
#  [False, 216, 0.0, 'positive'],
#  [True, 218, 2.0260000000000673, 'positive'],
#  [False, 219, -2.236000000000331, 'positive'],
#  [False, 220, -5.434999999999718, 'positive'],
#  [False, 221, 4.9849999999999, 'negative'],
#  [False, 222, -1.1001000000001113, 'positive'],
#  [True, 223, 6.7765666666666675, 'positive'],
#  [False, 224, -15.446466666666538, 'positive'],
#  [False, 225, 0.0, 'positive'],
#  [False, 226, 0.0, 'positive'],
#  [True, 227, 1.0, 'positive'],
#  [True, 228, 3.9539250000000266, 'positive'],
#  [False, 230, -2.9400000000000546, 'positive'],
#  [False, 231, 0.0, 'negative'],
#  [True, 232, 12.994374999999991, 'positive'],
#  [True, 234, 6.7374999999999545, 'positive'],
#  [False, 235, 0.0, 'positive'],
#  [False, 238, 0.6103400000001784, 'negative'],
#  [True, 239, 0.9146599999999125, 'positive'],
#  [True, 240, -0.1416666666666515, 'negative'],
#  [False, 243, 0.0, 'positive'],
#  [True, 249, -7.121859728506934, 'negative'],
#  [True, 252, 2.53670000000011, 'positive'],
#  [False, 253, -1.6133666666669342, 'positive'],
#  [True, 254, -8.775999999999613, 'negative'],
#  [True, 259, -0.7074999999999818, 'negative'],
#  [True, 261, -14.08541454545525, 'negative'],
#  [True, 262, -23.671804646464352, 'negative'],
#  [False, 263, 38.54036406619389, 'negative'],
#  [True, 264, 25.323228331466908, 'positive'],
#  [True, 275, 2.867803921568793, 'positive'],
#  [True, 277, 2.0966666666665787, 'positive'],
#  [True, 278, 6.186666666666497, 'positive'],
#  [True, 279, 4.698397619047682, 'positive'],
#  [True, 280, -17.355064285714207, 'negative'],
#  [False, 283, -4.9990999999999985, 'positive'],
#  [False, 284, 0.0, 'negative'],
#  [True, 285, -7.3024906250000186, 'negative'],
#  [False, 286, 2.2160141544118233, 'negative'],
#  [True, 287, -6.41342352941183, 'negative'],
#  [False, 290, 16.60141052631593, 'negative'],
#  [False, 293, -0.19000000000005457, 'positive'],
#  [False, 294, -6.614444444444416, 'positive'],
#  [False, 295, -8.250555555555593, 'positive'],
#  [False, 296, -2.8514000000002397, 'positive'],
#  [True, 298, -3.9697500000002037, 'negative'],
#  [False, 299, -4.517366666666703, 'positive'],
#  [False, 300, 1.4800000000000182, 'negative'],
#  [True, 302, 7.39627500000006, 'positive'],
#  [False, 303, -6.190000000000055, 'positive'],
#  [False, 305, -3.4042500000000473, 'positive'],
#  [True, 307, 9.475865384615417, 'positive'],
#  [False, 313, -3.8590909090910372, 'positive'],
#  [False, 314, -6.914134090908874, 'positive'],
#  [False, 316, 22.519230769230944, 'negative'],
#  [False, 318, 6.02800000000002, 'negative'],
#  [True, 323, 16.488571428571277, 'positive'],
#  [False, 324, -2.04257500000017, 'positive'],
#  [True, 326, 1.0694202380952902, 'positive'],
#  [False, 328, 0.0, 'positive'],
#  [False, 329, -11.93166666666616, 'positive'],
#  [False, 330, -4.2382208333337985, 'positive'],
#  [True, 332, 5.019999999999982, 'positive'],
#  [True, 333, -3.6041000000000167, 'negative'],
#  [False, 335, -7.2552333333335355, 'positive'],
#  [True, 336, -2.9322666666669193, 'negative'],
#  [False, 337, -25.84694444444426, 'positive'],
#  [False, 340, 0.0, 'positive'],
#  [False, 342, -8.569843859649154, 'positive'],
#  [True, 343, 4.0938666666665995, 'positive'],
#  [False, 344, 7.001666666666779, 'negative'],
#  [False, 347, -16.136157857142507, 'positive'],
#  [False, 348, 4.9889678571425975, 'negative'],
#  [True, 350, -3.535305882352759, 'negative'],
#  [True, 352, -4.255058823529453, 'negative'],
#  [False, 353, 3.5729499999999916, 'negative'],
#  [True, 354, 3.1816499999999905, 'positive'],
#  [True, 364, 13.420000000000073, 'positive'],
#  [True, 365, 0.27500000000009095, 'positive'],
#  [True, 366, 0.6949142857140487, 'positive'],
#  [False, 367, 6.976485714286127, 'negative'],
#  [False, 368, -6.857400000000325, 'positive'],
#  [False, 369, -5.259128571428619, 'positive'],
#  [True, 370, 0.8559035714285983, 'positive'],
#  [False, 371, -3.2766666666666424, 'positive'],
#  [False, 373, 0.0, 'negative'],
#  [False, 374, 0.0, 'positive'],
#  [False, 375, 0.0, 'positive'],
#  [False, 376, 0.0, 'positive'],
#  [False, 379, -2.410000000000082, 'positive'],
#  [False, 380, 3.8428888888890924, 'negative'],
#  [True, 382, 1.9948333333334176, 'positive'],
#  [False, 384, -2.6614999999999327, 'positive'],
#  [True, 385, 3.123333333333221, 'positive'],
#  [True, 387, 2.6055833333334704, 'positive'],
#  [False, 388, -5.098504545454716, 'positive'],
#  [True, 389, -6.208595454545275, 'negative'],
#  [True, 390, -3.9345499999999447, 'negative'],
#  [False, 391, -7.70900000000006, 'positive'],
#  [False, 396, -6.906571428571169, 'positive'],
#  [False, 397, -1.608528571429133, 'positive'],
#  [True, 398, 2.963555555556013, 'positive'],
#  [True, 399, 3.2823015873016175, 'positive'],
#  [True, 400, 2.7204761904758925, 'positive'],
#  [True, 401, 0.375, 'positive'],
#  [True, 402, 1.048666666666577, 'positive'],
#  [False, 403, -6.866999999999734, 'positive'],
#  [False, 404, -1.7916500000001179, 'positive'],
#  [True, 405, -33.42834999999991, 'negative'],
#  [True, 408, 6.585432773109005, 'positive'],
#  [True, 410, 2.4968250000001717, 'positive'],
#  [False, 411, -0.6818250000001171, 'positive'],
#  [True, 412, -4.797500000000127, 'negative'],
#  [True, 413, -3.7680999999997766, 'negative'],
#  [False, 414, -6.603566666666893, 'positive'],
#  [False, 415, -0.41583333333323935, 'positive'],
#  [True, 416, -26.704999999999927, 'negative'],
#  [False, 417, 0.0, 'negative'],
#  [False, 419, 0.0, 'positive'],
#  [False, 421, -0.5444444444444798, 'positive'],
#  [False, 425, -3.019999999999982, 'positive'],
#  [False, 427, -1.7999999999999545, 'positive'],
#  [False, 428, -8.866666666666788, 'positive'],
#  [False, 429, -45.10483333333332, 'positive'],
#  [True, 430, 7.521833333333461, 'positive'],
#  [True, 431, 1.219666666666626, 'positive'],
#  [True, 432, -23.1245550000001, 'negative'],
#  [False, 433, -1.2354449999997996, 'positive'],
#  [False, 434, -0.5150100000000748, 'positive'],
#  [True, 435, 7.998343333333423, 'positive'],
#  [True, 437, 21.73767460317481, 'positive'],
#  [True, 438, 8.671111111111031, 'positive'],
#  [False, 439, -1.6275000000000546, 'positive'],
#  [False, 440, -19.59101666666652, 'positive'],
#  [False, 447, 0.0, 'positive'],
#  [True, 451, 0.5621200000000499, 'positive'],
#  [True, 453, 2.483477777777807, 'positive'],
#  [False, 454, -1.633333333333212, 'positive'],
#  [False, 455, -4.270000000000209, 'positive'],
#  [True, 462, 12.556666666666615, 'positive'],
#  [False, 463, 12.034294444444413, 'negative'],
#  [True, 464, 24.634714327485426, 'positive'],
#  [False, 472, -5.130487499999845, 'positive'],
#  [True, 474, -4.271666666666761, 'negative'],
#  [True, 476, 9.697999999999865, 'positive'],
#  [False, 481, 0.0, 'positive'],
#  [True, 484, -5.875, 'negative'],
#  [False, 485, 2.619999999999891, 'negative'],
#  [False, 488, -0.39333333333343035, 'positive'],
#  [False, 490, -6.550228571428306, 'positive'],
#  [True, 491, -13.25298809523838, 'negative'],
#  [True, 497, 0.808333333333394, 'positive'],
#  [False, 498, -1.5043333333333067, 'positive'],
#  [False, 499, -11.534000000000333, 'positive'],
#  [True, 501, 0.2731333333333623, 'positive'],
#  [True, 502, 3.5735333333332164, 'positive'],
#  [True, 505, 1.0888317647059012, 'positive'],
#  [False, 506, -0.21311999999988984, 'positive'],
#  [True, 508, 6.058557142857126, 'positive'],
#  [True, 512, -1.8295500000001539, 'negative'],
#  [True, 514, -10.25, 'negative'],
#  [False, 515, 0.0, 'positive'],
#  [True, 518, 3.1964595238093807, 'positive'],
#  [True, 520, -1.494666666666717, 'negative'],
#  [True, 521, -0.007333333333235714, 'negative'],
#  [True, 522, 0.2599999999999909, 'positive'],
#  [False, 524, 5.329999999999927, 'negative'],
#  [False, 525, 0.0, 'positive'],
#  [False, 526, 0.0, 'positive'],
#  [False, 527, 0.0, 'positive'],
#  [False, 531, 0.4090909090909918, 'negative'],
#  [False, 532, -0.1674000000000433, 'positive'],
#  [True, 534, 0.9549999999999272, 'positive'],
#  [True, 535, -4.2094999999999345, 'negative'],
#  [False, 537, 0.0, 'positive'],
#  [True, 539, -0.7971250000000509, 'negative'],
#  [True, 543, -1.2367333333334045, 'negative'],
#  [False, 544, 0.49173333333374103, 'negative'],
#  [True, 545, 1.4624999999998636, 'positive'],
#  [True, 547, 1.6599944444444645, 'positive'],
#  [False, 548, 0.0, 'positive'],
#  [True, 550, 0.34666666666657875, 'positive'],
#  [True, 551, 0.08333333333348492, 'positive'],
#  [False, 552, -0.08752222222210548, 'positive'],
#  [False, 553, -4.0624777777779855, 'positive'],
#  [False, 554, -2.259999999999991, 'positive'],
#  [True, 557, -3.0738649999998415, 'negative'],
#  [True, 558, 1.6505316666666658, 'positive'],
#  [True, 562, 1.449999999999818, 'positive'],
#  [True, 563, -2.958245945946146, 'negative'],
#  [False, 566, -10.842810000000327, 'positive'],
#  [True, 568, 4.644500000000107, 'positive'],
#  [False, 570, 2.028649999999743, 'negative'],
#  [False, 573, -7.738250000000107, 'positive'],
#  [False, 574, -1.5670000000000073, 'positive'],
#  [True, 577, 0.60349999999994, 'positive'],
#  [True, 582, 4.100000000000136, 'positive'],
#  [True, 583, -0.1688166666667712, 'negative'],
#  [False, 585, -1.212500000000091, 'positive'],
#  [False, 587, -5.681739999999991, 'positive'],
#  [False, 590, 1.735824999999977, 'negative'],
#  [False, 591, 1.1694083333331946, 'negative'],
#  [False, 593, 2.1445249999999305, 'negative'],
#  [True, 594, 0.5511892857141447, 'positive'],
#  [True, 604, 3.799199999999928, 'positive'],
#  [False, 605, -9.961673333333238, 'positive'],
#  [False, 606, -8.017826666666679, 'positive'],
#  [False, 608, 16.719100000000026, 'negative'],
#  [False, 609, -2.5299999999999727, 'positive'],
#  [True, 610, 1.9803099999996903, 'positive'],
#  [False, 611, -1.511634999999842, 'positive'],
#  [True, 613, 1.4120250000000851, 'positive'],
#  [True, 617, -0.7057142857140661, 'negative'],
#  [True, 618, 5.545000000000073, 'positive'],
#  [False, 619, -1.0616666666667243, 'positive'],
#  [False, 622, -2.2793999999996686, 'positive'],
#  [True, 624, 3.3299999999999272, 'positive'],
#  [False, 625, 0.0, 'positive'],
#  [True, 626, 3.0499999999999545, 'positive'],
#  [False, 627, -0.049999999999954525, 'positive'],
#  [False, 628, -1.0, 'positive'],
#  [False, 631, -0.5533333333332848, 'positive'],
#  [True, 634, -5.6687500000000455, 'negative'],
#  [True, 635, -1.0342333333333045, 'negative'],
#  [False, 638, 0.0, 'negative'],
#  [False, 639, 0.0, 'positive'],
#  [True, 644, -2.8356903846154182, 'negative'],
#  [False, 645, 0.2853250000000571, 'negative'],
#  [True, 647, -2.730000000000018, 'negative'],
#  [True, 648, 0.13000000000010914, 'positive'],
#  [False, 649, -2.247100000000273, 'positive'],
#  [False, 650, -0.5246999999997115, 'positive'],
#  [True, 651, 0.03333499999985179, 'positive'],
#  [True, 652, 11.94846500000017, 'positive'],
#  [False, 653, 8.058333333333167, 'negative'],
#  [True, 654, -0.30999999999971806, 'negative'],
#  [True, 655, 0.09166666666646961, 'positive'],
#  [True, 657, 1.8027624999999716, 'positive'],
#  [False, 662, 0.4238166666664256, 'negative'],
#  [False, 665, 0.0, 'negative'],
#  [False, 666, 0.0, 'negative'],
#  [False, 667, 0.0, 'negative'],
#  [False, 668, 0.0, 'positive'],
#  [False, 669, 0.0, 'negative'],
#  [False, 670, 0.0, 'negative'],
#  [False, 673, 7.079127272726737, 'negative'],
#  [True, 674, 6.20230000000015, 'positive'],
#  [False, 676, -0.6680999999998676, 'positive'],
#  [False, 680, 0.0, 'positive'],
#  [True, 682, -1.25, 'negative'],
#  [False, 683, -2.849999999999909, 'positive'],
#  [True, 685, 1.0264285714283687, 'positive'],
#  [False, 687, 7.044466666666494, 'negative'],
#  [False, 688, 5.232200000000148, 'negative'],
#  [True, 690, -0.2339999999999236, 'negative'],
#  [False, 691, 1.5901800000001458, 'negative'],
#  [True, 692, 3.1638199999997596, 'positive'],
#  [True, 693, -0.2999999999999545, 'negative'],
#  [True, 695, 3.050944444443985, 'positive'],
#  [True, 699, -0.7999999999999545, 'negative'],
#  [False, 703, 1.4110250000001088, 'negative'],
#  [False, 704, 9.734000000000151, 'negative'],
#  [False, 705, 5.427499999999782, 'negative'],
#  [False, 707, 4.084800000000087, 'negative'],
#  [False, 709, 7.824563333333344, 'negative'],
#  [True, 711, 0.17416666666645142, 'positive'],
#  [False, 714, -1.4433333333333849, 'positive'],
#  [True, 715, 0.049999999999954525, 'positive'],
#  [False, 716, -2.0299999999999727, 'positive'],
#  [False, 717, -2.009999999999991, 'positive'],
#  [True, 719, 3.1616666666666333, 'positive'],
#  [True, 724, 9.542525000000069, 'positive'],
#  [False, 727, -0.05919999999991887, 'positive'],
#  [True, 729, 3.7842399999999543, 'positive'],
#  [True, 732, -1.0439809523811618, 'negative'],
#  [False, 741, -3.0967000000000553, 'positive'],
#  [False, 744, -4.330799999999954, 'positive'],
#  [False, 746, 0.0, 'positive'],
#  [False, 747, 2.4894999999999072, 'negative'],
#  [False, 748, -1.1381999999998698, 'positive'],
#  [True, 750, -6.500178571428705, 'negative'],
#  [False, 751, -18.5032850649352, 'positive'],
#  [False, 755, -0.49994999999989886, 'positive'],
#  [True, 757, 2.6218300000000454, 'positive'],
#  [False, 760, -2.3932999999997264, 'positive'],
#  [True, 761, 0.7008600000001479, 'positive'],
#  [False, 762, 4.159139999999752, 'negative'],
#  [False, 767, 0.0, 'positive'],
#  [False, 770, 0.0, 'positive'],
#  [False, 771, 0.0, 'positive'],
#  [False, 774, 0.0, 'negative'],
#  [True, 777, 0.3650000000000091, 'positive'],
#  [True, 778, 2.855000000000018, 'positive'],
#  [True, 779, 2.2210000000000036, 'positive'],
#  [False, 781, -0.006666666666887977, 'positive'],
#  [False, 783, -5.932000000000016, 'positive'],
#  [False, 788, -0.01999999999998181, 'positive'],
#  [False, 789, -1.6998000000000957, 'positive'],
#  [False, 790, 0.0, 'negative'],
#  [True, 791, 1.4798000000000684, 'positive'],
#  [False, 792, 2.355000000000018, 'negative'],
#  [True, 793, 4.787499999999909, 'positive'],
#  [True, 803, -0.15250000000014552, 'negative'],
#  [False, 804, 0.0, 'positive'],
#  [False, 809, -1.0066666666666606, 'positive'],
#  [True, 811, 0.8424999999999727, 'positive'],
#  [False, 812, -3.76929999999993, 'positive'],
#  [True, 813, 2.7708999999999833, 'positive'],
#  [False, 815, -2.855624999999918, 'positive'],
#  [False, 819, -5.58436666666671, 'positive'],
#  [True, 821, 1.0100000000002183, 'positive'],
#  [False, 822, 0.0, 'positive'],
#  [True, 823, 0.8399999999999181, 'positive'],
#  [False, 824, 1.2449999999998909, 'negative'],
#  [False, 829, -0.2833333333335304, 'positive'],
#  [False, 831, 0.0, 'positive'],
#  [False, 836, -2.900000000000091, 'positive'],
#  [False, 840, 0.0, 'negative'],
#  [False, 842, -0.4959999999998672, 'positive'],
#  [True, 844, 2.255000000000109, 'positive'],
#  [True, 845, 5.744999999999891, 'positive'],
#  [False, 847, -5.585000000000036, 'positive'],
#  [False, 848, -4.2733333333335395, 'positive'],
#  [True, 849, 1.1333333333336668, 'positive'],
#  [False, 852, -0.18499999999994543, 'positive'],
#  [False, 856, -1.0503333333333558, 'positive'],
#  [True, 857, 1.143333333333203, 'positive'],
#  [False, 859, -12.439209090909117, 'positive'],
#  [False, 860, -1.0700000000001637, 'positive'],
#  [True, 861, 4.542727272727461, 'positive'],
#  [False, 862, -14.650141666666741, 'positive'],
#  [False, 864, -0.3135250000000269, 'positive'],
#  [True, 865, 10.215524999999843, 'positive'],
#  [True, 866, 2.578000000000202, 'positive'],
#  [True, 867, 0.08333333333325754, 'positive'],
#  [False, 868, 2.339999999999918, 'negative'],
#  [False, 870, -4.533517142857136, 'positive'],
#  [False, 873, -14.527966666666998, 'positive'],
#  [False, 877, 0.0, 'positive'],
#  [False, 878, 0.0, 'negative'],
#  [False, 880, 0.0, 'negative'],
#  [False, 881, -0.83400000000006, 'positive'],
#  [True, 882, 1.1377500000000964, 'positive'],
#  [True, 883, 0.04624999999987267, 'positive'],
#  [True, 885, 3.8292999999998756, 'positive'],
#  [False, 886, -7.994999999999891, 'positive'],
#  [True, 887, 1.7116555555555806, 'positive'],
#  [True, 891, 1.6299999999998818, 'positive'],
#  [True, 892, 5.069999999999936, 'positive'],
#  [False, 893, -0.19000000000005457, 'positive'],
#  [False, 894, 0.257971428571409, 'negative'],
#  [False, 895, -5.167121428571363, 'positive'],
#  [False, 897, 3.9479318181818144, 'negative'],
#  [False, 900, 3.3199999999999363, 'negative'],
#  [False, 902, -0.02179999999998472, 'positive'],
#  [True, 903, 2.567355555555423, 'positive'],
#  [True, 904, 6.41944444444448, 'positive'],
#  [True, 906, 5.857714285714337, 'positive'],
#  [True, 907, 2.6872857142857356, 'positive'],
#  [False, 908, 0.0, 'positive'],
#  [True, 911, -3.72199999999998, 'negative'],
#  [True, 912, 2.939999999999827, 'positive'],
#  [True, 913, 4.193333333333612, 'positive'],
#  [False, 914, -3.886666666666997, 'positive'],
#  [True, 916, 3.465733333333219, 'positive'],
#  [True, 917, 0.5889999999999418, 'positive'],
#  [True, 919, 0.4500000000000455, 'positive'],
#  [False, 921, -3.276590909090828, 'positive'],
#  [True, 922, 4.2000000000000455, 'positive'],
#  [False, 923, -6.560500000000047, 'positive'],
#  [True, 924, -41.98949999999991, 'negative'],
#  [False, 925, 0.0, 'negative'],
#  [False, 926, 0.0, 'negative'],
#  [False, 928, 0.0, 'negative'],
#  [False, 929, 0.0, 'negative'],
#  [True, 930, -7.0, 'negative'],
#  [False, 931, 0.0, 'negative'],
#  [False, 932, 3.9700000000000273, 'negative'],
#  [True, 933, -3.8350000000000364, 'negative'],
#  [False, 934, -3.134999999999991, 'positive'],
#  [False, 935, 16.0, 'negative'],
#  [False, 936, 4.0, 'negative'],
#  [False, 937, 0.0, 'negative'],
#  [False, 938, 0.0, 'negative'],
#  [False, 941, 0.0, 'negative'],
#  [False, 942, 2.759999999999991, 'negative'],
#  [False, 943, 7.740000000000009, 'negative'],
#  [False, 944, -11.84615000000008, 'positive'],
#  [True, 945, -12.231849999999895, 'negative'],
#  [False, 946, -0.6794999999999618, 'positive'],
#  [False, 947, 1.8525499999998374, 'negative'],
#  [True, 948, 8.704950000000053, 'positive'],
#  [True, 949, 8.370000000000118, 'positive'],
#  [False, 950, -0.15499999999997272, 'positive'],
#  [False, 951, -6.504610000000184, 'positive'],
#  [True, 952, -0.04984555555552106, 'negative'],
#  [True, 953, 0.21945555555566898, 'positive'],
#  [False, 954, 0.0, 'positive'],
#  [False, 955, -1.7712500000002365, 'positive'],
#  [True, 957, -17.744609999999966, 'negative'],
#  [False, 961, -0.08268333333353439, 'positive'],
#  [False, 962, -0.17583333333345763, 'positive'],
#  [False, 967, -1.6625500000000102, 'positive'],
#  [True, 969, 0.942731666666532, 'positive'],
#  [False, 971, -1.6166666666665606, 'positive'],
#  [False, 972, -2.3688888888891597, 'positive'],
#  [True, 976, 3.9700000000000273, 'positive'],
#  [False, 977, -1.7436199999999644, 'positive'],
#  [False, 978, -10.714280000000144, 'positive'],
#  [True, 985, 8.980000000000018, 'positive'],
#  [False, 989, 3.740000000000009, 'negative'],
#  [False, 990, -2.31470000000013, 'positive'],
#  [True, 991, -4.290300000000116, 'negative'],
#  [True, 992, 2.9075000000002547, 'positive'],
#  [True, 993, -27.55416666666656, 'negative'],
#  [True, 996, -12.900433333333467, 'negative'],
#  [False, 998, 0.0, 'negative'],
#  [False, 1000, -0.5457142857142117, 'positive'],
#  [False, 1001, 3.27571428571423, 'negative'],
#  [False, 1007, 0.0, 'negative'],
#  [False, 1008, 0.0, 'negative'],
#  [True, 1009, -12.693333333333385, 'negative'],
#  [False, 1010, -5.0949999999998, 'positive'],
#  [True, 1011, -6.448566666666693, 'negative'],
#  [True, 1013, -9.652856666666821, 'negative'],
#  [True, 1014, -17.480893333333142, 'negative'],
#  [False, 1015, 4.25, 'negative'],
#  [True, 1017, -7.508499999999913, 'negative'],
#  [False, 1018, -19.39150000000018, 'positive'],
#  [True, 1021, 17.94056250000017, 'positive'],
#  [True, 1022, 2.70443750000004, 'positive'],
#  [False, 1023, -2.0783500000002277, 'positive'],
#  [False, 1026, -11.67104545454572, 'positive'],
#  [True, 1027, 20.063802597402628, 'positive'],
#  [True, 1028, -1.1808142857141775, 'negative'],
#  [True, 1029, 15.28578441558443, 'positive'],
#  [False, 1030, -25.52272727272748, 'positive'],
#  [False, 1031, -5.138749999999845, 'positive'],
#  [True, 1032, 7.242707142856943, 'positive'],
#  [False, 1034, -2.553333333333285, 'positive'],
#  [True, 1035, 8.774999999999864, 'positive'],
#  [True, 1039, -4.0833333333332575, 'negative'],
#  [True, 1040, 0.6547619047619264, 'positive'],
#  [False, 1042, 12.640242857143221, 'negative'],
#  [False, 1044, -0.4005966666668428, 'positive'],
#  [False, 1047, 3.312233333333552, 'negative'],
#  [True, 1052, -7.793385714285478, 'negative'],
#  [False, 1053, -6.919777777778108, 'positive'],
#  [False, 1054, -4.309999999999945, 'positive'],
#  [False, 1060, 22.06471428571399, 'negative'],
#  [False, 1061, 22.47928571428588, 'negative'],
#  [True, 1063, -3.6342999999999392, 'negative'],
#  [False, 1064, 4.515800000000127, 'negative'],
#  [True, 1065, -2.67650000000026, 'negative'],
#  [True, 1066, 5.273200000000088, 'positive'],
#  [True, 1067, 0.435399999999845, 'positive'],
#  [False, 1068, -1.1921714285711005, 'positive'],
#  [False, 1069, -23.514133333333348, 'positive'],
#  [False, 1070, -34.54727023809551, 'positive'],
#  [True, 1073, 8.435000000000173, 'positive'],
#  [False, 1076, -10.11999999999989, 'positive'],
#  [False, 1078, -2.763433333333296, 'positive'],
#  [True, 1081, 3.6710257575757623, 'positive'],
#  [False, 1083, 8.899912121212083, 'negative'],
#  [False, 1085, -1.543462499999805, 'positive'],
#  [False, 1088, 0.0, 'negative'],
#  [True, 1089, 4.463737500000207, 'positive'],
#  [True, 1090, 1.872895833333132, 'positive'],
#  [True, 1092, 0.772596666666459, 'positive'],
#  [True, 1093, 2.397403333333159, 'positive'],
#  [True, 1096, -0.5799999999999272, 'negative'],
#  [True, 1097, -6.951175000000148, 'negative'],
#  [False, 1100, -4.3888538461540065, 'positive'],
#  [True, 1101, -0.3532861538458292, 'negative'],
#  [True, 1102, 5.642139999999927, 'positive'],
#  [True, 1103, 3.2999999999999545, 'positive'],
#  [False, 1104, 0.0, 'positive'],
#  [True, 1105, 5.701471428571267, 'positive'],
#  [True, 1106, 1.2582035714285666, 'positive'],
#  [False, 1108, -3.460774545454342, 'positive'],
#  [True, 1109, 4.547953333333453, 'positive'],
#  [True, 1110, -4.14333333333343, 'negative'],
#  [True, 1111, 3.999000000000251, 'positive'],
#  [False, 1113, -16.436054166666736, 'positive'],
#  [False, 1114, 2.140566666666473, 'negative'],
#  [False, 1115, 0.8250000000002728, 'negative'],
#  [True, 1116, 1.2100000000000364, 'positive'],
#  [True, 1117, 2.239349999999831, 'positive'],
#  [True, 1118, -6.149885714285119, 'negative'],
#  [False, 1119, -14.340289285714789, 'positive'],
#  [True, 1122, -13.496133333333319, 'negative'],
#  [False, 1129, 15.05800000000022, 'negative'],
#  [False, 1132, -7.209375000000136, 'positive'],
#  [True, 1134, 1.2067357142859692, 'positive'],
#  [False, 1136, 0.8825625000001764, 'negative'],
#  [True, 1138, 3.655124999999771, 'positive'],
#  [True, 1139, 0.6566666666667516, 'positive'],
#  [False, 1140, -10.91594358974362, 'positive'],
#  [True, 1141, -16.07072307692306, 'negative'],
#  [True, 1142, 3.1900000000000546, 'positive'],
#  [True, 1143, 2.9516666666663696, 'positive'],
#  [True, 1144, 4.476666666666688, 'positive'],
#  [True, 1147, -1.0191964285713766, 'negative'],
#  [False, 1150, 15.814919565217906, 'negative'],
#  [True, 1151, 11.189621343873114, 'positive'],
#  [True, 1156, 9.837371428571714, 'positive'],
#  [True, 1158, -8.685000000000173, 'negative'],
#  [False, 1159, -8.05740000000037, 'positive'],
#  [True, 1162, -12.130349999999908, 'negative'],
#  [False, 1165, 0.0, 'positive'],
#  [True, 1166, 2.394615384615463, 'positive'],
#  [True, 1167, 5.330051282051272, 'positive'],
#  [True, 1168, 6.673333333332948, 'positive'],
#  [True, 1169, 16.13956250000024, 'positive'],
#  [False, 1170, 4.922437499999887, 'negative'],
#  [False, 1171, -4.968012499999759, 'positive'],
#  [False, 1172, -3.183767500000158, 'positive'],
#  [True, 1173, 0.6767924999999195, 'positive'],
#  [True, 1174, -2.2400124999999207, 'negative'],
#  [True, 1175, 1.125, 'positive'],
#  [True, 1177, 17.06218181818167, 'positive'],
#  [False, 1179, -3.5731399999999667, 'positive'],
#  [True, 1180, 3.3215600000000904, 'positive'],
#  [True, 1181, 1.478439999999864, 'positive'],
#  [True, 1183, 9.631666666666433, 'positive'],
#  [True, 1185, 5.4375, 'positive'],
#  [True, 1188, 3.3833058823529427, 'positive'],
#  [False, 1190, 1.1060500000000957, 'negative'],
#  [True, 1191, -0.19000000000005457, 'negative'],
#  [False, 1192, 2.5, 'negative'],
#  [False, 1193, 2.0, 'negative'],
#  [False, 1194, -2.16538461538471, 'positive'],
#  [False, 1195, -2.874615384615254, 'positive'],
#  [False, 1197, -1.9765933333335397, 'positive'],
#  [True, 1198, 0.6920833333333576, 'positive'],
#  [True, 1199, 2.6112499999999272, 'positive'],
#  [False, 1200, 0.0, 'positive'],
#  [False, 1201, 0.0, 'negative'],
#  [True, 1202, 2.3599999999999, 'positive'],
#  [True, 1203, 1.3400000000001455, 'positive'],
#  [False, 1205, -0.47250000000008185, 'positive'],
#  [False, 1207, -0.7339833333335264, 'positive'],
#  [True, 1208, 2.9716833333334307, 'positive'],
#  [True, 1209, -5.122699999999895, 'negative'],
#  [False, 1213, -3.400849999999764, 'positive'],
#  [True, 1214, -3.350280000000339, 'negative'],
#  [False, 1217, -2.2100000000000364, 'positive'],
#  [True, 1219, 4.753144444444615, 'positive'],
#  [True, 1223, 2.6061538461540295, 'positive'],
#  [False, 1224, 3.7349999999999, 'negative'],
#  [True, 1226, 0.24997499999994943, 'positive'],
#  [True, 1230, 12.940000000000282, 'positive'],
#  [False, 1231, -8.495714285714257, 'positive'],
#  [False, 1232, 0.8857142857143572, 'negative'],
#  [False, 1234, 4.439859999999953, 'negative'],
#  [False, 1245, 0.4622533333335923, 'negative'],
#  [True, 1246, 0.617113333333009, 'positive'],
#  [False, 1247, -5.348557142857089, 'positive'],
#  [True, 1249, -1.4909999999999854, 'negative'],
#  [False, 1250, -0.25644999999985885, 'positive'],
#  [False, 1253, -12.633611111110895, 'positive'],
#  [True, 1254, 3.012499999999818, 'positive'],
#  [False, 1255, -1.8599999999999, 'positive'],
#  [False, 1256, -0.9088166666665529, 'positive'],
#  [False, 1257, -2.081183333333456, 'positive'],
#  [False, 1260, -6.724514285714122, 'positive'],
#  [True, 1262, 1.1445181818182846, 'positive'],
#  [True, 1263, 1.9576923076924686, 'positive'],
#  [True, 1265, 0.6021666666665624, 'positive'],
#  [False, 1266, 5.426249999999982, 'negative'],
#  [True, 1267, 3.618750000000091, 'positive'],
#  [False, 1270, -1.4950000000001182, 'positive'],
#  [False, 1272, 1.2232999999996537, 'negative'],
#  [False, 1273, -0.4902999999997064, 'positive'],
#  [True, 1274, 0.22699999999986176, 'positive'],
#  [False, 1277, -2.597440000000006, 'positive'],
#  [False, 1279, -2.2737367544323206e-13, 'positive'],
#  [False, 1280, -3.0234999999997854, 'positive'],
#  [False, 1282, -3.034057142857364, 'positive'],
#  [False, 1283, -9.464102857142507, 'positive'],
#  [True, 1284, 16.972004444444337, 'positive'],
#  [False, 1285, -0.4094444444444889, 'positive'],
#  [True, 1286, -5.625, 'negative'],
#  [False, 1292, -0.01499999999987267, 'positive'],
#  [True, 1297, 1.0730000000000928, 'positive'],
#  [False, 1298, -2.4120000000000346, 'positive'],
#  [True, 1301, -2.1050000000002456, 'negative'],
#  [True, 1304, 0.525000000000091, 'positive'],
#  [True, 1305, 0.6294444444442888, 'positive'],
#  [False, 1306, -9.06461944444436, 'positive'],
#  [False, 1308, -10.85145000000034, 'positive'],
#  [False, 1314, 0.0, 'negative'],
#  [True, 1315, -1.5330000000001291, 'negative'],
#  [True, 1316, 3.5163333333334776, 'positive'],
#  [False, 1317, -11.98833333333323, 'positive'],
#  [True, 1318, -2.352100000000064, 'negative'],
#  [False, 1319, -0.9004999999999654, 'positive'],
#  [False, 1321, 2.2570285714284637, 'negative'],
#  [True, 1323, 2.644999999999982, 'positive'],
#  [True, 1325, 1.0513666666665813, 'positive'],
#  [True, 1329, 3.4985714285712675, 'positive'],
#  [False, 1330, 0.0, 'negative'],
#  [False, 1332, -0.8550000000000182, 'positive'],
#  [True, 1334, 0.4091666666668061, 'positive'],
#  [True, 1335, -5.588600000000042, 'negative'],
#  [False, 1336, -10.373900000000049, 'positive'],
#  [False, 1339, -11.541223076922734, 'positive'],
#  [True, 1343, 1.7077666666666573, 'positive'],
#  [False, 1347, 3.2365470588235894, 'negative'],
#  [False, 1348, 6.584433333333436, 'negative'],
#  [False, 1350, -12.05092499999978, 'positive'],
#  [True, 1351, 8.230924999999843, 'positive'],
#  [True, 1352, 2.9990000000000236, 'positive'],
#  [False, 1362, 0.0, 'positive'],
#  [False, 1369, 0.0, 'positive'],
#  [True, 1372, 1.5900000000001455, 'positive'],
#  [True, 1373, 2.7899999999999636, 'positive'],
#  [False, 1377, 0.0, 'positive'],
#  [False, 1378, 0.0, 'positive'],
#  [False, 1386, 0.0, 'positive'],
#  [False, 1403, 0.0, 'positive'],
#  [False, 1406, 0.0, 'negative'],
#  [False, 1409, -3.3016666666662786, 'positive'],
#  [True, 1413, -2.8040000000000873, 'negative'],
#  [False, 1414, -0.1959999999999127, 'positive'],
#  [True, 1415, 2.770000000000209, 'positive'],
#  [True, 1416, -2.5553333333336923, 'negative'],
#  [False, 1417, -10.426316666666708, 'positive'],
#  [True, 1418, 6.58121250000022, 'positive'],
#  [True, 1419, -12.62476249999986, 'negative'],
#  [True, 1420, -1.140633333333426, 'negative'],
#  [False, 1422, 0.0, 'positive'],
#  [False, 1423, 0.0, 'positive'],
#  [True, 1425, -2.847777777777992, 'negative'],
#  [False, 1426, -6.152922222221832, 'positive'],
#  [True, 1428, 6.3491333333336115, 'positive'],
#  [False, 1433, 0.7266666666664605, 'negative'],
#  [False, 1435, 0.0, 'positive'],
#  [True, 1439, 5.075714285714184, 'positive'],
#  [False, 1440, -0.06571428571419347, 'positive'],
#  [True, 1441, 1.949999999999818, 'positive'],
#  [True, 1442, 1.9833333333335759, 'positive'],
#  [False, 1444, -1.2523499999999785, 'positive'],
#  [False, 1449, -2.134233333332986, 'positive'],
#  [True, 1452, 3.141007692307994, 'positive'],
#  [False, 1456, -7.8129833333330225, 'positive'],
#  [True, 1457, 5.704999999999927, 'positive'],
#  [True, 1460, -2.3533333333334667, 'negative'],
#  [False, 1461, 3.7833583333338083, 'negative'],
#  [False, 1462, 3.254974999999604, 'negative'],
#  [False, 1466, -0.4125000000001364, 'positive'],
#  [True, 1469, 2.197499999999991, 'positive'],
#  [False, 1475, 0.0, 'negative'],
#  [False, 1477, -2.1800000000000637, 'positive'],
#  [False, 1480, -4.714135064934908, 'positive'],
#  [False, 1481, -1.8269696969698543, 'positive'],
#  [False, 1482, -9.6023809523806, 'positive'],
#  [False, 1483, -1.7242857142857702, 'positive'],
#  [False, 1485, -0.5072333333334882, 'positive'],
#  [True, 1486, -13.000307692307615, 'negative'],
#  [False, 1487, 16.16894102564106, 'negative'],
#  [False, 1490, -0.3914999999999509, 'positive'],
#  [True, 1491, 0.4386500000000524, 'positive'],
#  [False, 1492, 4.507849999999962, 'negative'],
#  [False, 1493, 0.7620916666667199, 'negative'],
#  [False, 1494, -3.2121416666668665, 'positive'],
#  [True, 1495, -11.467092857142688, 'negative'],
#  [True, 1496, -0.5928571428571558, 'negative'],
#  [False, 1498, 0.0, 'negative'],
#  [True, 1500, 11.280337500000087, 'positive'],
#  [False, 1501, -6.311187500000187, 'positive'],
#  [True, 1504, 1.648888888888905, 'positive'],
#  [False, 1506, 0.0, 'positive'],
#  [True, 1508, 1.1478571428572195, 'positive'],
#  [True, 1512, 1.5707142857143026, 'positive'],
#  [False, 1513, -0.5686000000000604, 'positive'],
#  [False, 1514, 0.0, 'positive'],
#  [False, 1515, -1.5663999999999305, 'positive'],
#  [True, 1517, -0.20306857142850276, 'negative'],
#  [True, 1520, -7.525000000000091, 'negative'],
#  [True, 1523, 1.4800000000002456, 'positive'],
#  [True, 1525, 0.8669916666665358, 'positive'],
#  [True, 1526, 0.10570000000029722, 'positive'],
#  [True, 1529, 1.4529999999999745, 'positive'],
#  [True, 1530, 5.605000000000018, 'positive'],
#  [False, 1531, -1.7833166666666784, 'positive'],
#  [True, 1532, -2.9866833333333034, 'negative'],
#  [True, 1534, 3.6500000000003183, 'positive'],
#  [False, 1535, -0.1671000000001186, 'positive'],
#  [True, 1537, 4.591133333333119, 'positive'],
#  [True, 1538, 4.266366666666727, 'positive'],
#  [False, 1539, 0.0, 'negative'],
#  [False, 1540, 1.4477999999999156, 'negative'],
#  [True, 1541, 2.5636500000002798, 'positive'],
#  [True, 1542, 2.390216666666447, 'positive'],
#  [False, 1545, 3.847433333333356, 'negative'],
#  [True, 1549, 4.0750000000000455, 'positive'],
#  [True, 1550, 0.724999999999909, 'positive'],
#  [True, 1551, 3.09681818181798, 'positive'],
#  [True, 1552, 6.603181818182065, 'positive'],
#  [False, 1553, 4.0275000000001455, 'negative'],
#  [False, 1554, -5.657650000000103, 'positive'],
#  [True, 1555, -3.5690166666670393, 'negative'],
#  [True, 1556, 5.344980952381093, 'positive'],
#  [False, 1557, 3.3541857142859044, 'negative'],
#  [True, 1558, -0.010000000000218279, 'negative'],
#  [True, 1559, 11.152500000000146, 'positive'],
#  [True, 1560, -0.13249999999993634, 'negative'],
#  [False, 1561, 1.4738499999998567, 'negative'],
#  [False, 1562, -6.69484999999986, 'positive'],
#  [False, 1565, -7.5811714285714515, 'positive'],
#  [True, 1566, 3.740000000000009, 'positive'],
#  [False, 1568, -15.643493939393693, 'positive'],
#  [False, 1570, -0.31708484848491025, 'positive'],
#  [True, 1571, 3.6591666666665787, 'positive'],
#  [False, 1574, 0.0, 'positive'],
#  [False, 1575, 0.0, 'negative'],
#  [False, 1577, 1.4099999999998545, 'negative'],
#  [True, 1578, 1.3639769230769616, 'positive'],
#  [True, 1579, 5.343989743589873, 'positive'],
#  [True, 1582, 1.0107500000001437, 'positive'],
#  [False, 1583, 0.9501000000000204, 'negative'],
#  [True, 1584, 0.48489999999992506, 'positive'],
#  [True, 1585, 3.9650000000001455, 'positive'],
#  [True, 1586, -0.2800000000002001, 'negative'],
#  [False, 1587, 0.0, 'positive'],
#  [False, 1588, -3.5623999999997977, 'positive'],
#  [True, 1589, -6.838133333333417, 'negative'],
#  [False, 1594, -4.667466666666542, 'positive'],
#  [False, 1595, -4.887950000000274, 'positive'],
#  [True, 1596, 1.5787500000001273, 'positive'],
#  [False, 1598, -1.4412500000000819, 'positive'],
#  [True, 1600, -8.667500000000018, 'negative'],
#  [False, 1601, 5.457499999999982, 'negative'],
#  [False, 1602, 8.979950000000144, 'negative'],
#  [True, 1605, 2.016212500000165, 'positive'],
#  [True, 1606, 2.3938200000002325, 'positive'],
#  [False, 1607, -0.18632000000025073, 'positive'],
#  [True, 1608, 0.25250000000005457, 'positive'],
#  [True, 1610, 1.290000000000191, 'positive'],
#  [False, 1611, -0.10999999999989996, 'positive'],
#  [True, 1613, 3.0850000000000364, 'positive'],
#  [True, 1616, 1.4200000000000728, 'positive'],
#  [False, 1617, -1.0299999999999727, 'positive'],
#  [True, 1620, -0.6090500000000247, 'negative'],
#  [True, 1623, -4.772699999999986, 'negative'],
#  [True, 1624, 4.686275000000023, 'positive'],
#  [True, 1627, 4.6666499999998905, 'positive'],
#  [False, 1628, -4.685849999999846, 'positive'],
#  [False, 1629, 1.2100000000000364, 'negative'],
#  [False, 1632, 4.421016666666674, 'negative'],
#  [True, 1633, -2.3675166666666883, 'negative'],
#  [True, 1634, 3.3560833333331175, 'positive'],
#  [True, 1635, -148.09333333333302, 'negative'],
#  [False, 1636, 0.0, 'negative'],
#  [False, 1637, 0.0, 'negative'],
#  [False, 1638, 0.0, 'positive'],
#  [True, 1639, 13.589999999999918, 'positive'],
#  [False, 1640, 0.0, 'negative'],
#  [False, 1641, 0.0, 'negative'],
#  [False, 1642, 0.0, 'positive'],
#  [False, 1643, 0.0, 'negative'],
#  [False, 1644, 0.0, 'negative'],
#  [False, 1645, 17.00999999999999, 'negative'],
#  [False, 1646, 0.0, 'negative'],
#  [True, 1647, -1.75, 'negative'],
#  [True, 1649, -5.125, 'negative'],
#  [False, 1650, 10.769999999999982, 'negative'],
#  [False, 1652, 0.0, 'positive'],
#  [False, 1653, 6.360000000000127, 'negative'],
#  [False, 1654, 0.0, 'positive'],
#  [False, 1655, 0.0, 'negative'],
#  [False, 1656, 0.0, 'negative'],
#  [False, 1657, 0.0, 'positive'],
#  [False, 1658, 0.0, 'negative'],
#  [False, 1659, 0.0, 'positive'],
#  [False, 1660, 0.0, 'negative'],
#  [False, 1661, 0.0, 'negative'],
#  [False, 1663, 0.0, 'negative'],
#  [False, 1664, 10.826000000000022, 'negative'],
#  [True, 1665, -5.522000000000162, 'negative'],
#  [True, 1667, -0.9897000000000844, 'negative'],
#  [False, 1668, 0.0, 'positive'],
#  [False, 1669, 0.0, 'negative'],
#  [False, 1670, 4.845000000000027, 'negative'],
#  [False, 1671, 16.144999999999982, 'negative'],
#  [True, 1672, 7.559999999999945, 'positive'],
#  [False, 1673, 0.0, 'positive'],
#  [False, 1674, 15.178000000000111, 'negative'],
#  [True, 1675, 4.761999999999944, 'positive'],
#  [False, 1676, 0.0, 'negative'],
#  [False, 1677, 10.25, 'negative'],
#  [False, 1679, 3.369999999999891, 'negative'],
#  [False, 1680, 0.0, 'negative'],
#  [False, 1681, 3.8600000000001273, 'negative'],
#  [True, 1682, 14.751124999999774, 'positive'],
#  [False, 1683, 2.198875000000271, 'negative'],
#  [True, 1684, -6.125000000000227, 'negative'],
#  [True, 1685, -2.4689999999998236, 'negative'],
#  [True, 1686, 6.034666666666681, 'positive'],
#  [False, 1689, 0.0, 'negative'],
#  [False, 1690, 0.0, 'positive'],
#  [False, 1692, 0.0, 'negative'],
#  [False, 1694, 0.0, 'negative'],
#  [True, 1695, -4.448750000000018, 'negative'],
#  [False, 1696, -0.7016799999998966, 'positive'],
#  [False, 1698, 7.307774999999992, 'negative'],
#  [True, 1699, 1.9431666666664569, 'positive'],
#  [False, 1701, 1.4220559523807879, 'negative'],
#  [False, 1703, -0.23500000000012733, 'positive'],
#  [False, 1704, -5.230000000000018, 'positive'],
#  [False, 1705, 0.0, 'negative'],
#  [False, 1706, 0.0, 'positive'],
#  [False, 1707, 0.0, 'positive'],
#  [False, 1710, 0.0, 'positive'],
#  [False, 1711, 2.3125, 'negative'],
#  [False, 1712, 2.6875, 'negative'],
#  [True, 1713, -0.029999999999972715, 'negative'],
#  [True, 1715, -5.581466666666756, 'negative'],
#  [False, 1716, -8.90978333333328, 'positive'],
#  [False, 1719, 0.4504523809523562, 'negative'],
#  [False, 1721, -2.336153846153593, 'positive'],
#  [True, 1723, 1.6679999999998927, 'positive'],
#  [False, 1725, -2.12720000000013, 'positive'],
#  [True, 1726, 7.967490000000225, 'positive'],
#  [False, 1727, -4.05021499999998, 'positive'],
#  [True, 1728, 1.3000249999997777, 'positive'],
#  [True, 1731, 8.160195312499809, 'positive'],
#  [False, 1732, 0.0, 'positive'],
#  [True, 1733, -2.598019999999906, 'negative'],
#  [False, 1734, -2.1119800000001305, 'positive'],
#  [True, 1735, 4.8275000000001, 'positive'],
#  [False, 1736, 3.9824999999998454, 'negative'],
#  [False, 1737, 1.5, 'negative'],
#  [False, 1738, -1.4968799999999192, 'positive'],
#  [True, 1740, 0.4771428571427805, 'positive'],
#  [False, 1742, 0.0, 'negative'],
#  [True, 1744, 8.860585294117527, 'positive'],
#  [True, 1746, -5.144666666666808, 'negative'],
#  [True, 1747, 3.9296666666666624, 'positive'],
#  [False, 1749, -0.6819307692310304, 'positive'],
#  [True, 1750, 0.7788750000001983, 'positive'],
#  [True, 1751, -0.6138750000000073, 'negative'],
#  [True, 1752, -1.6484999999997854, 'negative'],
#  [False, 1754, 1.136666666666315, 'negative'],
#  [False, 1758, -4.795316666666622, 'positive'],
#  [True, 1761, 6.570040000000063, 'positive'],
#  [True, 1764, -4.300000000000182, 'negative'],
#  [True, 1766, 1.5383333333331848, 'positive'],
#  [False, 1767, -1.062083333333021, 'positive'],
#  [True, 1768, -4.157934210526264, 'negative'],
#  [False, 1769, -10.962315789474133, 'positive'],
#  [False, 1773, 0.0, 'negative'],
#  [False, 1774, 0.0, 'positive'],
#  [False, 1775, 0.0, 'negative'],
#  [False, 1776, -0.8799999999998818, 'positive'],
#  [True, 1777, 0.44000000000005457, 'positive'],
#  [False, 1783, -0.15000000000009095, 'positive'],
#  [True, 1784, 0.4900000000000091, 'positive'],
#  [True, 1787, 0.4975299999998697, 'positive'],
#  [True, 1788, 1.0, 'positive'],
#  [True, 1793, -6.248026666666647, 'negative'],
#  [False, 1795, 0.7816666666669789, 'negative'],
#  [False, 1797, -4.909649999999829, 'positive'],
#  [True, 1798, -2.618533333333289, 'negative'],
#  [False, 1799, 0.6283333333333303, 'negative'],
#  [True, 1800, -2.451228571428601, 'negative'],
#  [True, 1801, -8.695894957983455, 'negative'],
#  [False, 1803, -0.30243333333328337, 'positive'],
#  [False, 1804, 2.1246000000001004, 'negative'],
#  [False, 1805, 9.07609999999977, 'negative'],
#  [True, 1806, -7.205711538461628, 'negative'],
#  [False, 1807, 2.235711538461601, 'negative'],
#  [False, 1811, 0.0, 'positive'],
#  [False, 1812, 0.0, 'negative'],
#  [False, 1813, 0.0, 'positive'],
#  [False, 1818, 3.877454545454384, 'negative'],
#  [True, 1822, 5.230000000000018, 'positive'],
#  [True, 1824, -3.4050000000002, 'negative'],
#  [False, 1825, -2.1949999999999363, 'positive'],
#  ...]

# %%
# Percentage of the average of the stock price differences (before and after publish) that 
# is supported by the sentiment of the roberta model
avg = sum([matching_with_sentiment[i][0] == True for i in range(len(matching_with_sentiment))]) / len(matching_with_sentiment)
print(f'Average percentage of times the articles\' sentiment matched the average stock price movement for Amazon is:\n {avg *100}')
# Out:
# Average percentage of times the articles' sentiment matched the average stock price movement for Amazon is:
#  43.159013103529695

# %%
[element for element in matching_with_sentiment if element[0] == False]
# Out:
# [[False, 1, -2.24048461538473, 'positive'],
#  [False, 4, -2.8864999999998417, 'positive'],
#  [False, 5, -7.229000000000042, 'positive'],
#  [False, 18, -7.677379679144224, 'positive'],
#  [False, 31, -7.7426297619049365, 'positive'],
#  [False, 32, -6.249991666666347, 'positive'],
#  [False, 34, -11.440000000000055, 'positive'],
#  [False, 42, -3.8013947981362435, 'positive'],
#  [False, 43, -21.05434396914461, 'positive'],
#  [False, 50, 0.0, 'positive'],
#  [False, 51, 0.0, 'positive'],
#  [False, 52, -2.986666666666679, 'positive'],
#  [False, 58, -0.27749999999991815, 'positive'],
#  [False, 62, -1.1700000000000728, 'positive'],
#  [False, 63, -2.7940000000000964, 'positive'],
#  [False, 64, 3.3756750000002285, 'negative'],
#  [False, 65, -1.1966750000001412, 'positive'],
#  [False, 68, -0.8638699999999062, 'positive'],
#  [False, 73, 0.0, 'positive'],
#  [False, 76, 1.71273846153872, 'negative'],
#  [False, 77, -7.256026470588267, 'positive'],
#  [False, 79, -2.2316666666663423, 'positive'],
#  [False, 83, -0.8664999999998599, 'positive'],
#  [False, 84, 1.2129999999999654, 'negative'],
#  [False, 92, 0.5201700000000073, 'negative'],
#  [False, 94, 2.445871428571536, 'negative'],
#  [False, 102, -4.396173333333309, 'positive'],
#  [False, 108, -2.735728205127998, 'positive'],
#  [False, 111, -0.5388888888890051, 'positive'],
#  [False, 115, -2.309422222222338, 'positive'],
#  [False, 119, -2.7109999999997854, 'positive'],
#  [False, 124, 0.5499999999999545, 'negative'],
#  [False, 139, -0.7599999999999909, 'positive'],
#  [False, 145, 2.5700000000001637, 'negative'],
#  [False, 146, 0.0, 'negative'],
#  [False, 148, 0.0, 'positive'],
#  [False, 149, 0.0, 'positive'],
#  [False, 150, 0.0, 'negative'],
#  [False, 152, -2.7480833333331702, 'positive'],
#  [False, 162, -1.4766666666666879, 'positive'],
#  [False, 166, -0.24037499999963075, 'positive'],
#  [False, 169, 2.79982121212106, 'negative'],
#  [False, 172, -3.153830769230808, 'positive'],
#  [False, 173, 0.0, 'positive'],
#  [False, 174, 0.0, 'positive'],
#  [False, 176, -2.598830769230517, 'positive'],
#  [False, 178, 7.108140178571375, 'negative'],
#  [False, 182, -0.005000000000109139, 'positive'],
#  [False, 190, -7.357300000000123, 'positive'],
#  [False, 192, -5.007341666666662, 'positive'],
#  [False, 196, 5.308987999999999, 'negative'],
#  [False, 203, -4.638416666666444, 'positive'],
#  [False, 204, -4.616583333333438, 'positive'],
#  [False, 205, 0.0, 'positive'],
#  [False, 206, 15.450000000000045, 'negative'],
#  [False, 208, 0.0, 'negative'],
#  [False, 213, 0.0, 'negative'],
#  [False, 215, 0.0, 'positive'],
#  [False, 216, 0.0, 'positive'],
#  [False, 219, -2.236000000000331, 'positive'],
#  [False, 220, -5.434999999999718, 'positive'],
#  [False, 221, 4.9849999999999, 'negative'],
#  [False, 222, -1.1001000000001113, 'positive'],
#  [False, 224, -15.446466666666538, 'positive'],
#  [False, 225, 0.0, 'positive'],
#  [False, 226, 0.0, 'positive'],
#  [False, 230, -2.9400000000000546, 'positive'],
#  [False, 231, 0.0, 'negative'],
#  [False, 235, 0.0, 'positive'],
#  [False, 238, 0.6103400000001784, 'negative'],
#  [False, 243, 0.0, 'positive'],
#  [False, 253, -1.6133666666669342, 'positive'],
#  [False, 263, 38.54036406619389, 'negative'],
#  [False, 283, -4.9990999999999985, 'positive'],
#  [False, 284, 0.0, 'negative'],
#  [False, 286, 2.2160141544118233, 'negative'],
#  [False, 290, 16.60141052631593, 'negative'],
#  [False, 293, -0.19000000000005457, 'positive'],
#  [False, 294, -6.614444444444416, 'positive'],
#  [False, 295, -8.250555555555593, 'positive'],
#  [False, 296, -2.8514000000002397, 'positive'],
#  [False, 299, -4.517366666666703, 'positive'],
#  [False, 300, 1.4800000000000182, 'negative'],
#  [False, 303, -6.190000000000055, 'positive'],
#  [False, 305, -3.4042500000000473, 'positive'],
#  [False, 313, -3.8590909090910372, 'positive'],
#  [False, 314, -6.914134090908874, 'positive'],
#  [False, 316, 22.519230769230944, 'negative'],
#  [False, 318, 6.02800000000002, 'negative'],
#  [False, 324, -2.04257500000017, 'positive'],
#  [False, 328, 0.0, 'positive'],
#  [False, 329, -11.93166666666616, 'positive'],
#  [False, 330, -4.2382208333337985, 'positive'],
#  [False, 335, -7.2552333333335355, 'positive'],
#  [False, 337, -25.84694444444426, 'positive'],
#  [False, 340, 0.0, 'positive'],
#  [False, 342, -8.569843859649154, 'positive'],
#  [False, 344, 7.001666666666779, 'negative'],
#  [False, 347, -16.136157857142507, 'positive'],
#  [False, 348, 4.9889678571425975, 'negative'],
#  [False, 353, 3.5729499999999916, 'negative'],
#  [False, 367, 6.976485714286127, 'negative'],
#  [False, 368, -6.857400000000325, 'positive'],
#  [False, 369, -5.259128571428619, 'positive'],
#  [False, 371, -3.2766666666666424, 'positive'],
#  [False, 373, 0.0, 'negative'],
#  [False, 374, 0.0, 'positive'],
#  [False, 375, 0.0, 'positive'],
#  [False, 376, 0.0, 'positive'],
#  [False, 379, -2.410000000000082, 'positive'],
#  [False, 380, 3.8428888888890924, 'negative'],
#  [False, 384, -2.6614999999999327, 'positive'],
#  [False, 388, -5.098504545454716, 'positive'],
#  [False, 391, -7.70900000000006, 'positive'],
#  [False, 396, -6.906571428571169, 'positive'],
#  [False, 397, -1.608528571429133, 'positive'],
#  [False, 403, -6.866999999999734, 'positive'],
#  [False, 404, -1.7916500000001179, 'positive'],
#  [False, 411, -0.6818250000001171, 'positive'],
#  [False, 414, -6.603566666666893, 'positive'],
#  [False, 415, -0.41583333333323935, 'positive'],
#  [False, 417, 0.0, 'negative'],
#  [False, 419, 0.0, 'positive'],
#  [False, 421, -0.5444444444444798, 'positive'],
#  [False, 425, -3.019999999999982, 'positive'],
#  [False, 427, -1.7999999999999545, 'positive'],
#  [False, 428, -8.866666666666788, 'positive'],
#  [False, 429, -45.10483333333332, 'positive'],
#  [False, 433, -1.2354449999997996, 'positive'],
#  [False, 434, -0.5150100000000748, 'positive'],
#  [False, 439, -1.6275000000000546, 'positive'],
#  [False, 440, -19.59101666666652, 'positive'],
#  [False, 447, 0.0, 'positive'],
#  [False, 454, -1.633333333333212, 'positive'],
#  [False, 455, -4.270000000000209, 'positive'],
#  [False, 463, 12.034294444444413, 'negative'],
#  [False, 472, -5.130487499999845, 'positive'],
#  [False, 481, 0.0, 'positive'],
#  [False, 485, 2.619999999999891, 'negative'],
#  [False, 488, -0.39333333333343035, 'positive'],
#  [False, 490, -6.550228571428306, 'positive'],
#  [False, 498, -1.5043333333333067, 'positive'],
#  [False, 499, -11.534000000000333, 'positive'],
#  [False, 506, -0.21311999999988984, 'positive'],
#  [False, 515, 0.0, 'positive'],
#  [False, 524, 5.329999999999927, 'negative'],
#  [False, 525, 0.0, 'positive'],
#  [False, 526, 0.0, 'positive'],
#  [False, 527, 0.0, 'positive'],
#  [False, 531, 0.4090909090909918, 'negative'],
#  [False, 532, -0.1674000000000433, 'positive'],
#  [False, 537, 0.0, 'positive'],
#  [False, 544, 0.49173333333374103, 'negative'],
#  [False, 548, 0.0, 'positive'],
#  [False, 552, -0.08752222222210548, 'positive'],
#  [False, 553, -4.0624777777779855, 'positive'],
#  [False, 554, -2.259999999999991, 'positive'],
#  [False, 566, -10.842810000000327, 'positive'],
#  [False, 570, 2.028649999999743, 'negative'],
#  [False, 573, -7.738250000000107, 'positive'],
#  [False, 574, -1.5670000000000073, 'positive'],
#  [False, 585, -1.212500000000091, 'positive'],
#  [False, 587, -5.681739999999991, 'positive'],
#  [False, 590, 1.735824999999977, 'negative'],
#  [False, 591, 1.1694083333331946, 'negative'],
#  [False, 593, 2.1445249999999305, 'negative'],
#  [False, 605, -9.961673333333238, 'positive'],
#  [False, 606, -8.017826666666679, 'positive'],
#  [False, 608, 16.719100000000026, 'negative'],
#  [False, 609, -2.5299999999999727, 'positive'],
#  [False, 611, -1.511634999999842, 'positive'],
#  [False, 619, -1.0616666666667243, 'positive'],
#  [False, 622, -2.2793999999996686, 'positive'],
#  [False, 625, 0.0, 'positive'],
#  [False, 627, -0.049999999999954525, 'positive'],
#  [False, 628, -1.0, 'positive'],
#  [False, 631, -0.5533333333332848, 'positive'],
#  [False, 638, 0.0, 'negative'],
#  [False, 639, 0.0, 'positive'],
#  [False, 645, 0.2853250000000571, 'negative'],
#  [False, 649, -2.247100000000273, 'positive'],
#  [False, 650, -0.5246999999997115, 'positive'],
#  [False, 653, 8.058333333333167, 'negative'],
#  [False, 662, 0.4238166666664256, 'negative'],
#  [False, 665, 0.0, 'negative'],
#  [False, 666, 0.0, 'negative'],
#  [False, 667, 0.0, 'negative'],
#  [False, 668, 0.0, 'positive'],
#  [False, 669, 0.0, 'negative'],
#  [False, 670, 0.0, 'negative'],
#  [False, 673, 7.079127272726737, 'negative'],
#  [False, 676, -0.6680999999998676, 'positive'],
#  [False, 680, 0.0, 'positive'],
#  [False, 683, -2.849999999999909, 'positive'],
#  [False, 687, 7.044466666666494, 'negative'],
#  [False, 688, 5.232200000000148, 'negative'],
#  [False, 691, 1.5901800000001458, 'negative'],
#  [False, 703, 1.4110250000001088, 'negative'],
#  [False, 704, 9.734000000000151, 'negative'],
#  [False, 705, 5.427499999999782, 'negative'],
#  [False, 707, 4.084800000000087, 'negative'],
#  [False, 709, 7.824563333333344, 'negative'],
#  [False, 714, -1.4433333333333849, 'positive'],
#  [False, 716, -2.0299999999999727, 'positive'],
#  [False, 717, -2.009999999999991, 'positive'],
#  [False, 727, -0.05919999999991887, 'positive'],
#  [False, 741, -3.0967000000000553, 'positive'],
#  [False, 744, -4.330799999999954, 'positive'],
#  [False, 746, 0.0, 'positive'],
#  [False, 747, 2.4894999999999072, 'negative'],
#  [False, 748, -1.1381999999998698, 'positive'],
#  [False, 751, -18.5032850649352, 'positive'],
#  [False, 755, -0.49994999999989886, 'positive'],
#  [False, 760, -2.3932999999997264, 'positive'],
#  [False, 762, 4.159139999999752, 'negative'],
#  [False, 767, 0.0, 'positive'],
#  [False, 770, 0.0, 'positive'],
#  [False, 771, 0.0, 'positive'],
#  [False, 774, 0.0, 'negative'],
#  [False, 781, -0.006666666666887977, 'positive'],
#  [False, 783, -5.932000000000016, 'positive'],
#  [False, 788, -0.01999999999998181, 'positive'],
#  [False, 789, -1.6998000000000957, 'positive'],
#  [False, 790, 0.0, 'negative'],
#  [False, 792, 2.355000000000018, 'negative'],
#  [False, 804, 0.0, 'positive'],
#  [False, 809, -1.0066666666666606, 'positive'],
#  [False, 812, -3.76929999999993, 'positive'],
#  [False, 815, -2.855624999999918, 'positive'],
#  [False, 819, -5.58436666666671, 'positive'],
#  [False, 822, 0.0, 'positive'],
#  [False, 824, 1.2449999999998909, 'negative'],
#  [False, 829, -0.2833333333335304, 'positive'],
#  [False, 831, 0.0, 'positive'],
#  [False, 836, -2.900000000000091, 'positive'],
#  [False, 840, 0.0, 'negative'],
#  [False, 842, -0.4959999999998672, 'positive'],
#  [False, 847, -5.585000000000036, 'positive'],
#  [False, 848, -4.2733333333335395, 'positive'],
#  [False, 852, -0.18499999999994543, 'positive'],
#  [False, 856, -1.0503333333333558, 'positive'],
#  [False, 859, -12.439209090909117, 'positive'],
#  [False, 860, -1.0700000000001637, 'positive'],
#  [False, 862, -14.650141666666741, 'positive'],
#  [False, 864, -0.3135250000000269, 'positive'],
#  [False, 868, 2.339999999999918, 'negative'],
#  [False, 870, -4.533517142857136, 'positive'],
#  [False, 873, -14.527966666666998, 'positive'],
#  [False, 877, 0.0, 'positive'],
#  [False, 878, 0.0, 'negative'],
#  [False, 880, 0.0, 'negative'],
#  [False, 881, -0.83400000000006, 'positive'],
#  [False, 886, -7.994999999999891, 'positive'],
#  [False, 893, -0.19000000000005457, 'positive'],
#  [False, 894, 0.257971428571409, 'negative'],
#  [False, 895, -5.167121428571363, 'positive'],
#  [False, 897, 3.9479318181818144, 'negative'],
#  [False, 900, 3.3199999999999363, 'negative'],
#  [False, 902, -0.02179999999998472, 'positive'],
#  [False, 908, 0.0, 'positive'],
#  [False, 914, -3.886666666666997, 'positive'],
#  [False, 921, -3.276590909090828, 'positive'],
#  [False, 923, -6.560500000000047, 'positive'],
#  [False, 925, 0.0, 'negative'],
#  [False, 926, 0.0, 'negative'],
#  [False, 928, 0.0, 'negative'],
#  [False, 929, 0.0, 'negative'],
#  [False, 931, 0.0, 'negative'],
#  [False, 932, 3.9700000000000273, 'negative'],
#  [False, 934, -3.134999999999991, 'positive'],
#  [False, 935, 16.0, 'negative'],
#  [False, 936, 4.0, 'negative'],
#  [False, 937, 0.0, 'negative'],
#  [False, 938, 0.0, 'negative'],
#  [False, 941, 0.0, 'negative'],
#  [False, 942, 2.759999999999991, 'negative'],
#  [False, 943, 7.740000000000009, 'negative'],
#  [False, 944, -11.84615000000008, 'positive'],
#  [False, 946, -0.6794999999999618, 'positive'],
#  [False, 947, 1.8525499999998374, 'negative'],
#  [False, 950, -0.15499999999997272, 'positive'],
#  [False, 951, -6.504610000000184, 'positive'],
#  [False, 954, 0.0, 'positive'],
#  [False, 955, -1.7712500000002365, 'positive'],
#  [False, 961, -0.08268333333353439, 'positive'],
#  [False, 962, -0.17583333333345763, 'positive'],
#  [False, 967, -1.6625500000000102, 'positive'],
#  [False, 971, -1.6166666666665606, 'positive'],
#  [False, 972, -2.3688888888891597, 'positive'],
#  [False, 977, -1.7436199999999644, 'positive'],
#  [False, 978, -10.714280000000144, 'positive'],
#  [False, 989, 3.740000000000009, 'negative'],
#  [False, 990, -2.31470000000013, 'positive'],
#  [False, 998, 0.0, 'negative'],
#  [False, 1000, -0.5457142857142117, 'positive'],
#  [False, 1001, 3.27571428571423, 'negative'],
#  [False, 1007, 0.0, 'negative'],
#  [False, 1008, 0.0, 'negative'],
#  [False, 1010, -5.0949999999998, 'positive'],
#  [False, 1015, 4.25, 'negative'],
#  [False, 1018, -19.39150000000018, 'positive'],
#  [False, 1023, -2.0783500000002277, 'positive'],
#  [False, 1026, -11.67104545454572, 'positive'],
#  [False, 1030, -25.52272727272748, 'positive'],
#  [False, 1031, -5.138749999999845, 'positive'],
#  [False, 1034, -2.553333333333285, 'positive'],
#  [False, 1042, 12.640242857143221, 'negative'],
#  [False, 1044, -0.4005966666668428, 'positive'],
#  [False, 1047, 3.312233333333552, 'negative'],
#  [False, 1053, -6.919777777778108, 'positive'],
#  [False, 1054, -4.309999999999945, 'positive'],
#  [False, 1060, 22.06471428571399, 'negative'],
#  [False, 1061, 22.47928571428588, 'negative'],
#  [False, 1064, 4.515800000000127, 'negative'],
#  [False, 1068, -1.1921714285711005, 'positive'],
#  [False, 1069, -23.514133333333348, 'positive'],
#  [False, 1070, -34.54727023809551, 'positive'],
#  [False, 1076, -10.11999999999989, 'positive'],
#  [False, 1078, -2.763433333333296, 'positive'],
#  [False, 1083, 8.899912121212083, 'negative'],
#  [False, 1085, -1.543462499999805, 'positive'],
#  [False, 1088, 0.0, 'negative'],
#  [False, 1100, -4.3888538461540065, 'positive'],
#  [False, 1104, 0.0, 'positive'],
#  [False, 1108, -3.460774545454342, 'positive'],
#  [False, 1113, -16.436054166666736, 'positive'],
#  [False, 1114, 2.140566666666473, 'negative'],
#  [False, 1115, 0.8250000000002728, 'negative'],
#  [False, 1119, -14.340289285714789, 'positive'],
#  [False, 1129, 15.05800000000022, 'negative'],
#  [False, 1132, -7.209375000000136, 'positive'],
#  [False, 1136, 0.8825625000001764, 'negative'],
#  [False, 1140, -10.91594358974362, 'positive'],
#  [False, 1150, 15.814919565217906, 'negative'],
#  [False, 1159, -8.05740000000037, 'positive'],
#  [False, 1165, 0.0, 'positive'],
#  [False, 1170, 4.922437499999887, 'negative'],
#  [False, 1171, -4.968012499999759, 'positive'],
#  [False, 1172, -3.183767500000158, 'positive'],
#  [False, 1179, -3.5731399999999667, 'positive'],
#  [False, 1190, 1.1060500000000957, 'negative'],
#  [False, 1192, 2.5, 'negative'],
#  [False, 1193, 2.0, 'negative'],
#  [False, 1194, -2.16538461538471, 'positive'],
#  [False, 1195, -2.874615384615254, 'positive'],
#  [False, 1197, -1.9765933333335397, 'positive'],
#  [False, 1200, 0.0, 'positive'],
#  [False, 1201, 0.0, 'negative'],
#  [False, 1205, -0.47250000000008185, 'positive'],
#  [False, 1207, -0.7339833333335264, 'positive'],
#  [False, 1213, -3.400849999999764, 'positive'],
#  [False, 1217, -2.2100000000000364, 'positive'],
#  [False, 1224, 3.7349999999999, 'negative'],
#  [False, 1231, -8.495714285714257, 'positive'],
#  [False, 1232, 0.8857142857143572, 'negative'],
#  [False, 1234, 4.439859999999953, 'negative'],
#  [False, 1245, 0.4622533333335923, 'negative'],
#  [False, 1247, -5.348557142857089, 'positive'],
#  [False, 1250, -0.25644999999985885, 'positive'],
#  [False, 1253, -12.633611111110895, 'positive'],
#  [False, 1255, -1.8599999999999, 'positive'],
#  [False, 1256, -0.9088166666665529, 'positive'],
#  [False, 1257, -2.081183333333456, 'positive'],
#  [False, 1260, -6.724514285714122, 'positive'],
#  [False, 1266, 5.426249999999982, 'negative'],
#  [False, 1270, -1.4950000000001182, 'positive'],
#  [False, 1272, 1.2232999999996537, 'negative'],
#  [False, 1273, -0.4902999999997064, 'positive'],
#  [False, 1277, -2.597440000000006, 'positive'],
#  [False, 1279, -2.2737367544323206e-13, 'positive'],
#  [False, 1280, -3.0234999999997854, 'positive'],
#  [False, 1282, -3.034057142857364, 'positive'],
#  [False, 1283, -9.464102857142507, 'positive'],
#  [False, 1285, -0.4094444444444889, 'positive'],
#  [False, 1292, -0.01499999999987267, 'positive'],
#  [False, 1298, -2.4120000000000346, 'positive'],
#  [False, 1306, -9.06461944444436, 'positive'],
#  [False, 1308, -10.85145000000034, 'positive'],
#  [False, 1314, 0.0, 'negative'],
#  [False, 1317, -11.98833333333323, 'positive'],
#  [False, 1319, -0.9004999999999654, 'positive'],
#  [False, 1321, 2.2570285714284637, 'negative'],
#  [False, 1330, 0.0, 'negative'],
#  [False, 1332, -0.8550000000000182, 'positive'],
#  [False, 1336, -10.373900000000049, 'positive'],
#  [False, 1339, -11.541223076922734, 'positive'],
#  [False, 1347, 3.2365470588235894, 'negative'],
#  [False, 1348, 6.584433333333436, 'negative'],
#  [False, 1350, -12.05092499999978, 'positive'],
#  [False, 1362, 0.0, 'positive'],
#  [False, 1369, 0.0, 'positive'],
#  [False, 1377, 0.0, 'positive'],
#  [False, 1378, 0.0, 'positive'],
#  [False, 1386, 0.0, 'positive'],
#  [False, 1403, 0.0, 'positive'],
#  [False, 1406, 0.0, 'negative'],
#  [False, 1409, -3.3016666666662786, 'positive'],
#  [False, 1414, -0.1959999999999127, 'positive'],
#  [False, 1417, -10.426316666666708, 'positive'],
#  [False, 1422, 0.0, 'positive'],
#  [False, 1423, 0.0, 'positive'],
#  [False, 1426, -6.152922222221832, 'positive'],
#  [False, 1433, 0.7266666666664605, 'negative'],
#  [False, 1435, 0.0, 'positive'],
#  [False, 1440, -0.06571428571419347, 'positive'],
#  [False, 1444, -1.2523499999999785, 'positive'],
#  [False, 1449, -2.134233333332986, 'positive'],
#  [False, 1456, -7.8129833333330225, 'positive'],
#  [False, 1461, 3.7833583333338083, 'negative'],
#  [False, 1462, 3.254974999999604, 'negative'],
#  [False, 1466, -0.4125000000001364, 'positive'],
#  [False, 1475, 0.0, 'negative'],
#  [False, 1477, -2.1800000000000637, 'positive'],
#  [False, 1480, -4.714135064934908, 'positive'],
#  [False, 1481, -1.8269696969698543, 'positive'],
#  [False, 1482, -9.6023809523806, 'positive'],
#  [False, 1483, -1.7242857142857702, 'positive'],
#  [False, 1485, -0.5072333333334882, 'positive'],
#  [False, 1487, 16.16894102564106, 'negative'],
#  [False, 1490, -0.3914999999999509, 'positive'],
#  [False, 1492, 4.507849999999962, 'negative'],
#  [False, 1493, 0.7620916666667199, 'negative'],
#  [False, 1494, -3.2121416666668665, 'positive'],
#  [False, 1498, 0.0, 'negative'],
#  [False, 1501, -6.311187500000187, 'positive'],
#  [False, 1506, 0.0, 'positive'],
#  [False, 1513, -0.5686000000000604, 'positive'],
#  [False, 1514, 0.0, 'positive'],
#  [False, 1515, -1.5663999999999305, 'positive'],
#  [False, 1531, -1.7833166666666784, 'positive'],
#  [False, 1535, -0.1671000000001186, 'positive'],
#  [False, 1539, 0.0, 'negative'],
#  [False, 1540, 1.4477999999999156, 'negative'],
#  [False, 1545, 3.847433333333356, 'negative'],
#  [False, 1553, 4.0275000000001455, 'negative'],
#  [False, 1554, -5.657650000000103, 'positive'],
#  [False, 1557, 3.3541857142859044, 'negative'],
#  [False, 1561, 1.4738499999998567, 'negative'],
#  [False, 1562, -6.69484999999986, 'positive'],
#  [False, 1565, -7.5811714285714515, 'positive'],
#  [False, 1568, -15.643493939393693, 'positive'],
#  [False, 1570, -0.31708484848491025, 'positive'],
#  [False, 1574, 0.0, 'positive'],
#  [False, 1575, 0.0, 'negative'],
#  [False, 1577, 1.4099999999998545, 'negative'],
#  [False, 1583, 0.9501000000000204, 'negative'],
#  [False, 1587, 0.0, 'positive'],
#  [False, 1588, -3.5623999999997977, 'positive'],
#  [False, 1594, -4.667466666666542, 'positive'],
#  [False, 1595, -4.887950000000274, 'positive'],
#  [False, 1598, -1.4412500000000819, 'positive'],
#  [False, 1601, 5.457499999999982, 'negative'],
#  [False, 1602, 8.979950000000144, 'negative'],
#  [False, 1607, -0.18632000000025073, 'positive'],
#  [False, 1611, -0.10999999999989996, 'positive'],
#  [False, 1617, -1.0299999999999727, 'positive'],
#  [False, 1628, -4.685849999999846, 'positive'],
#  [False, 1629, 1.2100000000000364, 'negative'],
#  [False, 1632, 4.421016666666674, 'negative'],
#  [False, 1636, 0.0, 'negative'],
#  [False, 1637, 0.0, 'negative'],
#  [False, 1638, 0.0, 'positive'],
#  [False, 1640, 0.0, 'negative'],
#  [False, 1641, 0.0, 'negative'],
#  [False, 1642, 0.0, 'positive'],
#  [False, 1643, 0.0, 'negative'],
#  [False, 1644, 0.0, 'negative'],
#  [False, 1645, 17.00999999999999, 'negative'],
#  [False, 1646, 0.0, 'negative'],
#  [False, 1650, 10.769999999999982, 'negative'],
#  [False, 1652, 0.0, 'positive'],
#  [False, 1653, 6.360000000000127, 'negative'],
#  [False, 1654, 0.0, 'positive'],
#  [False, 1655, 0.0, 'negative'],
#  [False, 1656, 0.0, 'negative'],
#  [False, 1657, 0.0, 'positive'],
#  [False, 1658, 0.0, 'negative'],
#  [False, 1659, 0.0, 'positive'],
#  [False, 1660, 0.0, 'negative'],
#  [False, 1661, 0.0, 'negative'],
#  [False, 1663, 0.0, 'negative'],
#  [False, 1664, 10.826000000000022, 'negative'],
#  [False, 1668, 0.0, 'positive'],
#  [False, 1669, 0.0, 'negative'],
#  [False, 1670, 4.845000000000027, 'negative'],
#  [False, 1671, 16.144999999999982, 'negative'],
#  [False, 1673, 0.0, 'positive'],
#  [False, 1674, 15.178000000000111, 'negative'],
#  [False, 1676, 0.0, 'negative'],
#  [False, 1677, 10.25, 'negative'],
#  [False, 1679, 3.369999999999891, 'negative'],
#  [False, 1680, 0.0, 'negative'],
#  [False, 1681, 3.8600000000001273, 'negative'],
#  [False, 1683, 2.198875000000271, 'negative'],
#  [False, 1689, 0.0, 'negative'],
#  [False, 1690, 0.0, 'positive'],
#  [False, 1692, 0.0, 'negative'],
#  [False, 1694, 0.0, 'negative'],
#  [False, 1696, -0.7016799999998966, 'positive'],
#  [False, 1698, 7.307774999999992, 'negative'],
#  [False, 1701, 1.4220559523807879, 'negative'],
#  [False, 1703, -0.23500000000012733, 'positive'],
#  [False, 1704, -5.230000000000018, 'positive'],
#  [False, 1705, 0.0, 'negative'],
#  [False, 1706, 0.0, 'positive'],
#  [False, 1707, 0.0, 'positive'],
#  [False, 1710, 0.0, 'positive'],
#  [False, 1711, 2.3125, 'negative'],
#  [False, 1712, 2.6875, 'negative'],
#  [False, 1716, -8.90978333333328, 'positive'],
#  [False, 1719, 0.4504523809523562, 'negative'],
#  [False, 1721, -2.336153846153593, 'positive'],
#  [False, 1725, -2.12720000000013, 'positive'],
#  [False, 1727, -4.05021499999998, 'positive'],
#  [False, 1732, 0.0, 'positive'],
#  [False, 1734, -2.1119800000001305, 'positive'],
#  [False, 1736, 3.9824999999998454, 'negative'],
#  [False, 1737, 1.5, 'negative'],
#  [False, 1738, -1.4968799999999192, 'positive'],
#  [False, 1742, 0.0, 'negative'],
#  [False, 1749, -0.6819307692310304, 'positive'],
#  [False, 1754, 1.136666666666315, 'negative'],
#  [False, 1758, -4.795316666666622, 'positive'],
#  [False, 1767, -1.062083333333021, 'positive'],
#  [False, 1769, -10.962315789474133, 'positive'],
#  [False, 1773, 0.0, 'negative'],
#  [False, 1774, 0.0, 'positive'],
#  [False, 1775, 0.0, 'negative'],
#  [False, 1776, -0.8799999999998818, 'positive'],
#  [False, 1783, -0.15000000000009095, 'positive'],
#  [False, 1795, 0.7816666666669789, 'negative'],
#  [False, 1797, -4.909649999999829, 'positive'],
#  [False, 1799, 0.6283333333333303, 'negative'],
#  [False, 1803, -0.30243333333328337, 'positive'],
#  [False, 1804, 2.1246000000001004, 'negative'],
#  [False, 1805, 9.07609999999977, 'negative'],
#  [False, 1807, 2.235711538461601, 'negative'],
#  [False, 1811, 0.0, 'positive'],
#  [False, 1812, 0.0, 'negative'],
#  [False, 1813, 0.0, 'positive'],
#  [False, 1818, 3.877454545454384, 'negative'],
#  [False, 1825, -2.1949999999999363, 'positive'],
#  [False, 1827, 1.1892454545454711, 'negative'],
#  [False, 1831, 4.657500000000027, 'negative'],
#  [False, 1839, -6.460000000000036, 'positive'],
#  [False, 1841, 7.447499999999991, 'negative'],
#  [False, 1846, -0.37799999999992906, 'positive'],
#  [False, 1851, -4.10078055555573, 'positive'],
#  [False, 1852, -15.1102249999999, 'positive'],
#  [False, 1860, -2.9333333333336213, 'positive'],
#  [False, 1862, -3.8227166666667927, 'positive'],
#  [False, 1867, 0.6088666666664722, 'negative'],
#  [False, 1868, -2.4394666666667035, 'positive'],
#  [False, 1872, 0.0, 'positive'],
#  [False, 1874, 0.0, 'negative'],
#  [False, 1875, 0.0, 'positive'],
#  [False, 1877, 0.0, 'positive'],
#  [False, 1881, 0.6316666666664332, 'negative'],
#  [False, 1884, 0.0, 'positive'],
#  [False, 1890, 0.5546666666668898, 'negative'],
#  [False, 1893, 1.6549999999999727, 'negative'],
#  [False, 1894, 0.9850000000001273, 'negative'],
#  [False, 1898, -0.46250000000009095, 'positive'],
#  [False, 1901, 0.42000000000007276, 'negative'],
#  [False, 1902, 0.9923666666668396, 'negative'],
#  [False, 1905, 1.4458557692310023, 'negative'],
#  [False, 1907, 4.1897435897437845, 'negative'],
#  [False, 1910, 11.52512857142824, 'negative'],
#  [False, 1912, -6.357776666666268, 'positive'],
#  [False, 1914, 0.0, 'positive'],
#  [False, 1916, 0.0, 'positive'],
#  [False, 1919, -0.5199999999999818, 'positive'],
#  [False, 1922, -2.65930000000003, 'positive'],
#  [False, 1932, -7.472500000000082, 'positive'],
#  [False, 1943, -0.4971399999997175, 'positive'],
#  [False, 1946, -3.7641666666668243, 'positive'],
#  [False, 1947, 0.0, 'positive'],
#  [False, 1948, 0.0, 'positive'],
#  [False, 1950, -7.420000000000073, 'positive'],
#  [False, 1951, -4.38666666666677, 'positive'],
#  [False, 1952, -3.1189999999999145, 'positive'],
#  [False, 1954, -1.6085000000000491, 'positive'],
#  [False, 1958, 0.0, 'positive'],
#  [False, 1970, -0.5392230769227808, 'positive'],
#  [False, 1973, 0.0, 'positive'],
#  [False, 1974, -1.7800000000002, 'positive'],
#  [False, 1978, -2.142383333333555, 'positive'],
#  [False, 1981, -1.3975000000000364, 'positive'],
#  [False, 1982, -6.089999999999918, 'positive'],
#  [False, 1992, -3.882333333333463, 'positive'],
#  [False, 1996, -4.556612500000256, 'positive'],
#  [False, 1998, 0.0, 'positive'],
#  [False, 2004, 0.9850000000001273, 'negative'],
#  [False, 2012, 0.0, 'positive'],
#  [False, 2014, 0.0, 'positive'],
#  [False, 2016, 0.0, 'positive'],
#  [False, 2019, 0.0, 'negative'],
#  [False, 2020, 0.0, 'negative'],
#  [False, 2022, 0.0, 'positive'],
#  [False, 2023, 0.0, 'positive'],
#  [False, 2024, 0.0, 'negative'],
#  [False, 2027, 8.364799999999832, 'negative'],
#  [False, 2031, -1.0795750000002045, 'positive'],
#  [False, 2032, 0.8051749999999629, 'negative'],
#  [False, 2034, 0.0, 'negative'],
#  [False, 2035, -0.8199999999999363, 'positive'],
#  [False, 2037, 1.4671000000000731, 'negative'],
#  [False, 2039, -1.928433333333487, 'positive'],
#  [False, 2041, -3.8259999999997945, 'positive'],
#  [False, 2043, 7.555000000000064, 'negative'],
#  [False, 2050, 0.17666666666673336, 'negative'],
#  [False, 2054, -2.2847840909093975, 'positive'],
#  [False, 2055, 8.479492424242608, 'negative'],
#  [False, 2062, 1.623472727272656, 'negative'],
#  [False, 2064, -0.8875923076921026, 'positive'],
#  [False, 2065, -1.2124076923078064, 'positive'],
#  [False, 2067, -0.9756666666667115, 'positive'],
#  [False, 2071, -2.4700000000000273, 'positive'],
#  [False, 2075, 0.0, 'positive'],
#  [False, 2076, 0.0, 'positive'],
#  [False, 2077, -1.2000000000000455, 'positive'],
#  [False, 2078, -1.2001999999999953, 'positive'],
#  [False, 2079, 0.0, 'positive'],
#  [False, 2085, 2.56135634920588, 'negative'],
#  [False, 2089, -2.4346999999997934, 'positive'],
#  [False, 2095, -1.0150000000001, 'positive'],
#  [False, 2097, -0.9800000000000182, 'positive'],
#  [False, 2099, 0.0, 'positive'],
#  [False, 2100, -1.45962499999996, 'positive'],
#  [False, 2107, 1.0, 'negative'],
#  [False, 2108, -0.3713857142854522, 'positive'],
#  [False, 2114, 2.2126428571427823, 'negative'],
#  [False, 2119, -1.3139444444445871, 'positive'],
#  [False, 2122, 0.0, 'positive'],
#  [False, 2123, -0.20000000000004547, 'positive'],
#  [False, 2125, -1.7991583333330254, 'positive'],
#  [False, 2126, -1.1465416666667352, 'positive'],
#  [False, 2129, 3.866631944444407, 'negative'],
#  [False, 2131, -2.671846666666852, 'positive'],
#  [False, 2132, -2.255277777777792, 'positive'],
#  [False, 2149, 6.436923076922767, 'negative'],
#  [False, 2155, 0.8700000000001182, 'negative'],
#  [False, 2158, -4.778333333333421, 'positive'],
#  [False, 2161, -0.7114285714283142, 'positive'],
#  [False, 2163, 0.0, 'positive'],
#  [False, 2164, 0.0, 'positive'],
#  [False, 2165, -4.630000000000109, 'positive'],
#  [False, 2168, -14.406772222222116, 'positive'],
#  [False, 2170, -4.519224285714245, 'positive'],
#  [False, 2176, 3.342616666666572, 'negative'],
#  [False, 2177, -3.08095000000003, 'positive'],
#  [False, 2178, 1.8226666666666915, 'negative'],
#  [False, 2179, 5.570113333333438, 'negative'],
#  [False, 2181, 0.0, 'negative'],
#  [False, 2182, 0.0, 'negative'],
#  [False, 2189, 2.002916666666806, 'negative'],
#  [False, 2191, -16.271016666666355, 'positive'],
#  [False, 2192, 0.0, 'positive'],
#  [False, 2193, 0.0, 'positive'],
#  [False, 2194, 0.0, 'positive'],
#  [False, 2196, 0.0, 'positive'],
#  [False, 2197, 0.0, 'positive'],
#  [False, 2198, 0.0, 'positive'],
#  [False, 2202, 0.0, 'positive'],
#  [False, 2210, -1.2567599999997583, 'positive'],
#  [False, 2215, -1.1154714285714817, 'positive'],
#  [False, 2216, -3.674528571428482, 'positive'],
#  [False, 2224, 0.834999999999809, 'negative'],
#  [False, 2225, -0.4600000000000364, 'positive'],
#  [False, 2228, -9.690000000000055, 'positive'],
#  [False, 2230, 11.7433424242422, 'negative'],
#  [False, 2239, -8.596735714285614, 'positive'],
#  [False, 2240, -6.673264285714367, 'positive'],
#  [False, 2246, 0.0, 'positive'],
#  [False, 2247, 0.42200000000002547, 'negative'],
#  [False, 2248, -0.07449999999994361, 'positive'],
#  [False, 2265, -3.2097400000000107, 'positive'],
#  [False, 2266, -2.8821100000000115, 'positive'],
#  [False, 2276, -5.667303703703965, 'positive'],
#  [False, 2279, 4.757142857142753, 'negative'],
#  [False, 2280, -0.15000000000009095, 'positive'],
#  [False, 2283, 3.809216666666771, 'negative'],
#  [False, 2284, -9.21053333333316, 'positive'],
#  [False, 2286, 10.490276190475925, 'negative'],
#  [False, 2287, 0.0, 'positive'],
#  [False, 2288, 0.0, 'positive'],
#  [False, 2291, -0.558875000000171, 'positive'],
#  [False, 2292, -6.191124999999829, 'positive'],
#  [False, 2295, -0.748299999999972, 'positive'],
#  [False, 2297, 0.0, 'positive'],
#  [False, 2298, 0.0, 'negative'],
#  [False, 2299, 0.0, 'positive'],
#  [False, 2300, 0.0, 'positive'],
#  [False, 2302, 0.0, 'negative'],
#  [False, 2306, 0.0, 'negative'],
#  [False, 2308, 1.5271000000000186, 'negative'],
#  [False, 2309, 4.25, 'negative'],
#  [False, 2310, 5.942739999999731, 'negative'],
#  [False, 2311, -5.16773999999964, 'positive'],
#  [False, 2313, 21.856514999999945, 'negative'],
#  [False, 2316, -3.2803250000001754, 'positive'],
#  [False, 2318, -0.5787500000001273, 'positive'],
#  [False, 2319, -4.5462500000001, 'positive'],
#  [False, 2320, 0.0, 'positive'],
#  [False, 2321, -2.166666666666515, 'positive'],
#  [False, 2324, -0.9156181818182176, 'positive'],
#  [False, 2326, -2.8500833333332594, 'positive'],
#  [False, 2329, 0.23335833333317169, 'negative'],
#  [False, 2332, -6.928622222222202, 'positive'],
#  [False, 2335, -13.752499999999827, 'positive'],
#  [False, 2339, 0.6268200000001798, 'negative'],
#  [False, 2344, -3.6876375000001644, 'positive'],
#  [False, 2346, 1.9249750000001313, 'negative'],
#  [False, 2350, -1.838333333333594, 'positive'],
#  [False, 2355, 2.3871428571430897, 'negative'],
#  [False, 2357, 4.721666666666579, 'negative'],
#  [False, 2358, 9.179608333333363, 'negative'],
#  [False, 2360, 0.37000000000011823, 'negative'],
#  [False, 2361, 2.9699999999998, 'negative'],
#  [False, 2372, 4.048523809523658, 'negative'],
#  [False, 2373, -2.727966666666589, 'positive'],
#  [False, 2374, 3.026299999999992, 'negative'],
#  [False, 2375, -1.0536999999999352, 'positive'],
#  [False, 2378, 7.941666666666606, 'negative'],
#  [False, 2380, 3.1017000000001644, 'negative'],
#  [False, 2381, -0.9958500000000186, 'positive'],
#  [False, 2384, 0.0, 'positive'],
#  [False, 2385, 0.0, 'positive'],
#  [False, 2387, 0.0, 'positive'],
#  [False, 2388, 0.0, 'positive'],
#  [False, 2389, 0.0, 'positive'],
#  [False, 2390, 0.0, 'positive'],
#  [False, 2391, 0.0, 'positive'],
#  [False, 2392, 0.0, 'positive'],
#  [False, 2394, -64.22000000000025, 'positive'],
#  [False, 2395, 0.0, 'positive'],
#  [False, 2396, 0.0, 'positive'],
#  [False, 2397, 0.0, 'positive'],
#  [False, 2398, 0.0, 'positive'],
#  [False, 2399, 0.0, 'positive'],
#  [False, 2400, 0.0, 'positive'],
#  [False, 2401, 0.0, 'positive'],
#  [False, 2402, 0.0, 'positive'],
#  [False, 2403, 0.0, 'positive'],
#  [False, 2405, 0.0, 'positive'],
#  [False, 2406, 0.0, 'negative'],
#  [False, 2408, 0.34222222222206256, 'negative'],
#  [False, 2413, 1.631800000000112, 'negative'],
#  [False, 2417, 0.0, 'positive'],
#  [False, 2420, -41.50499999999988, 'positive'],
#  [False, 2421, 0.0, 'positive'],
#  [False, 2425, -1.8161999999999807, 'positive'],
#  [False, 2426, 0.0, 'positive'],
#  [False, 2427, 4.116200000000163, 'negative'],
#  [False, 2429, 0.0, 'positive'],
#  [False, 2431, -11.240000000000009, 'positive'],
#  [False, 2433, 0.0, 'positive'],
#  [False, 2435, -7.807749999999942, 'positive'],
#  [False, 2437, -6.589516666666896, 'positive'],
#  [False, 2442, 0.0, 'positive'],
#  [False, 2443, 0.0, 'positive'],
#  [False, 2446, -0.19166666666706078, 'positive'],
#  [False, 2448, 7.147483333333412, 'negative'],
#  [False, 2449, 1.6574833333334027, 'negative'],
#  [False, 2456, -5.128999999999905, 'positive'],
#  [False, 2466, 3.336333333332732, 'negative'],
#  [False, 2468, -19.536000000000058, 'positive'],
#  [False, 2469, -16.104000000000042, 'positive'],
#  [False, 2472, -2.721112337662589, 'positive'],
#  [False, 2474, -7.135460000000421, 'positive'],
#  [False, 2483, -2.8400000000001455, 'positive'],
#  [False, 2484, 1.6800000000000637, 'negative'],
#  [False, 2485, 0.0, 'negative'],
#  [False, 2490, -0.48178571428525174, 'positive'],
#  [False, 2492, 0.0, 'positive'],
#  [False, 2494, 0.0, 'negative'],
#  [False, 2495, 0.0, 'negative'],
#  [False, 2496, 3.430000000000291, 'negative'],
#  [False, 2497, 3.89042500000005, 'negative'],
#  [False, 2499, 34.73196666666672, 'negative'],
#  [False, 2507, 0.0, 'negative'],
#  [False, 2510, 4.309179999999742, 'negative'],
#  [False, 2517, 0.8716666666668971, 'negative'],
#  [False, 2526, -0.32084942528717875, 'positive'],
#  [False, 2529, -3.3066749999998137, 'positive'],
#  [False, 2533, -7.924683333333178, 'positive'],
#  [False, 2537, -7.9548545454540545, 'positive'],
#  [False, 2540, -0.2725749999999607, 'positive'],
#  [False, 2545, 0.0, 'negative'],
#  [False, 2546, 0.0, 'positive'],
#  [False, 2547, 0.0, 'positive'],
#  [False, 2549, 0.0, 'negative'],
#  [False, 2550, 0.0, 'negative'],
#  [False, 2551, 0.0, 'negative'],
#  [False, 2554, -3.4149999999999636, 'positive'],
#  [False, 2555, -6.42975000000024, 'positive'],
#  [False, 2556, -1.2452499999999418, 'positive'],
#  [False, 2564, 12.873235294117876, 'negative'],
#  [False, 2573, 3.671366666666472, 'negative'],
#  [False, 2580, -8.163415151514982, 'positive'],
#  [False, 2583, 0.0, 'positive'],
#  [False, 2588, -15.772150000000238, 'positive'],
#  [False, 2589, -3.179099999999835, 'positive'],
#  [False, 2593, -0.6168249999998352, 'positive'],
#  [False, 2595, 5.368181818181938, 'negative'],
#  [False, 2604, -3.142199999999548, 'positive'],
#  [False, 2605, -9.334315789473521, 'positive'],
#  [False, 2607, -21.086353333333363, 'positive'],
#  [False, 2609, 5.909768750000012, 'negative'],
#  [False, 2613, 0.0, 'positive'],
#  [False, 2616, -24.037500000000136, 'positive'],
#  [False, 2617, 11.681950000000143, 'negative'],
#  [False, 2620, 0.4800000000000182, 'negative'],
#  [False, 2621, 8.849999999999909, 'negative'],
#  [False, 2624, 32.4231833333331, 'negative'],
#  [False, 2629, -21.590666666666948, 'positive'],
#  [False, 2632, -9.483516666666446, 'positive'],
#  [False, 2636, 24.28148095238066, 'negative'],
#  [False, 2639, -6.009999999999991, 'positive'],
#  [False, 2640, -4.752500000000055, 'positive'],
#  [False, 2642, -1.164700000000039, 'positive'],
#  [False, 2644, -36.255441666666684, 'positive'],
#  [False, 2653, 20.742726623377166, 'negative'],
#  [False, 2655, -1.8950000000002092, 'positive'],
#  [False, 2666, 0.0, 'positive'],
#  [False, 2674, -11.319999999999936, 'positive'],
#  [False, 2683, -9.309349999999995, 'positive'],
#  [False, 2684, -2.9500000000000455, 'positive'],
#  [False, 2688, -25.71036666666646, 'positive'],
#  [False, 2693, 13.828571428571422, 'negative'],
#  [False, 2695, -5.644525000000158, 'positive'],
#  [False, 2699, -12.071959999999763, 'positive'],
#  [False, 2700, -2.841699999999946, 'positive'],
#  [False, 2702, 0.0, 'positive'],
#  [False, 2707, 0.0, 'positive'],
#  [False, 2711, -75.4699999999998, 'positive'],
#  [False, 2716, -9.576716666666698, 'positive'],
#  [False, 2728, 0.0, 'positive'],
#  [False, 2731, 45.70843600000012, 'negative'],
#  [False, 2734, 0.0, 'positive'],
#  [False, 2735, 0.0, 'negative'],
#  [False, 2739, 11.814444444444462, 'negative'],
#  [False, 2742, 28.422600000000102, 'negative'],
#  [False, 2744, -28.920000000000073, 'positive'],
#  [False, 2745, 5.182000000000016, 'negative'],
#  [False, 2747, -7.352570000000014, 'positive'],
#  [False, 2749, 0.0, 'positive'],
#  [False, 2750, -0.8800000000001091, 'positive'],
#  [False, 2751, 0.0, 'positive'],
#  [False, 2755, -12.7650000000001, 'positive'],
#  [False, 2760, 0.0, 'positive'],
#  [False, 2761, -44.852499999999964, 'positive'],
#  [False, 2763, -4.154166666666924, 'positive'],
#  [False, 2764, -20.89749999999981, 'positive'],
#  [False, 2767, 0.0, 'negative'],
#  [False, 2770, 24.663333333333185, 'negative'],
#  [False, 2772, 0.0, 'positive'],
#  [False, 2773, 24.58750000000009, 'negative'],
#  [False, 2775, -28.14130000000023, 'positive'],
#  [False, 2778, 29.299600000000055, 'negative'],
#  [False, 2788, 0.0, 'positive'],
#  [False, 2795, 13.756583333333083, 'negative'],
#  [False, 2799, 27.992500000000064, 'negative'],
#  [False, 2802, -12.586666666667043, 'positive'],
#  [False, 2804, 10.002500000000055, 'negative'],
#  [False, 2809, 4.954999999999927, 'negative'],
#  [False, 2813, 1.1247999999998228, 'negative'],
#  [False, 2819, 91.53999999999996, 'negative'],
#  [False, 2820, 0.0, 'positive'],
#  [False, 2821, 0.0, 'positive'],
#  [False, 2822, 9.869687500000055, 'negative'],
#  [False, 2823, -41.27468750000003, 'positive'],
#  [False, 2825, -18.46939999999995, 'positive'],
#  [False, 2827, -7.787942857143207, 'positive'],
#  [False, 2828, -4.565866666666807, 'positive'],
#  [False, 2829, -14.698266666666541, 'positive'],
#  [False, 2833, 0.0, 'negative'],
#  [False, 2834, 0.0, 'negative'],
#  [False, 2835, 0.0, 'positive'],
#  [False, 2836, 0.0, 'negative'],
#  [False, 2837, 0.0, 'positive'],
#  [False, 2838, 0.0, 'positive'],
#  [False, 2839, 0.0, 'negative'],
#  [False, 2843, 0.0, 'positive'],
#  [False, 2844, 0.0, 'negative'],
#  [False, 2845, 0.0, 'positive'],
#  [False, 2848, 0.0, 'negative'],
#  [False, 2851, 3.070416666666688, 'negative'],
#  [False, 2857, 34.72517999999991, 'negative'],
#  [False, 2864, 49.46444444444455, 'negative'],
#  [False, 2866, -17.33666666666636, 'positive'],
#  [False, 2872, -2.035777777778094, 'positive'],
#  [False, 2875, 20.492177777777897, 'negative'],
#  [False, 2876, 3.453622222222066, 'negative'],
#  [False, 2877, 4.2775000000001455, 'negative'],
#  [False, 2878, -4.597500000000082, 'positive'],
#  [False, 2880, 0.0, 'negative'],
#  [False, 2883, -16.589947058823327, 'positive'],
#  [False, 2885, -1.2049999999999272, 'positive'],
#  [False, 2888, 5.125, 'negative'],
#  [False, 2889, 4.1525000000001455, 'negative'],
#  [False, 2890, 8.617499999999836, 'negative'],
#  [False, 2899, 11.546319444444634, 'negative'],
#  [False, 2900, 2.8876249999998436, 'negative'],
#  [False, 2902, 4.954200000000128, 'negative'],
#  [False, 2903, -2.7427000000000135, 'positive'],
#  [False, 2920, 0.0, 'positive'],
#  [False, 2923, 0.0, 'negative'],
#  [False, 2930, 17.02000000000021, 'negative'],
#  [False, 2932, 0.0, 'positive'],
#  [False, 2933, 6.137399999999843, 'negative'],
#  [False, 2934, 1.7976000000001022, 'negative'],
#  [False, 2947, 2.3150000000000546, 'negative'],
#  [False, 2948, 0.0, 'negative'],
#  [False, 2949, 20.0, 'negative'],
#  [False, 2951, 0.0, 'negative'],
#  [False, 2952, 0.0, 'negative'],
#  [False, 2953, 0.0, 'positive'],
#  [False, 2956, 0.0, 'positive'],
#  [False, 2957, 2.0, 'negative'],
#  [False, 2959, -8.072500000000218, 'positive'],
#  [False, 2961, 17.845605681817915, 'negative'],
#  [False, 2968, -0.7400000000000091, 'positive'],
#  [False, 2969, -1.5699999999999363, 'positive'],
#  [False, 2980, 5.608877777777934, 'negative'],
#  [False, 2994, -6.970000000000027, 'positive'],
#  [False, 3000, 2.5, 'negative'],
#  [False, 3001, 0.0, 'negative'],
#  [False, 3002, -8.049999999999955, 'positive'],
#  [False, 3008, -3.609375, 'positive'],
#  [False, 3012, 11.04778095238089, 'negative'],
#  [False, 3013, -1.7366666666666788, 'positive'],
#  [False, 3014, 0.5775000000001, 'negative'],
#  [False, 3017, 0.0, 'negative'],
#  [False, 3018, 0.0, 'positive'],
#  [False, 3019, 0.0, 'negative'],
#  [False, 3023, 18.026749999999993, 'negative'],
#  [False, 3030, 1.2025000000001, 'negative'],
#  [False, 3040, 1.8074999999998909, 'negative'],
#  [False, 3045, 8.067483333333257, 'negative'],
#  [False, 3052, 0.0, 'negative'],
#  [False, 3053, -1.0750000000000455, 'positive'],
#  [False, 3058, 17.053614285714502, 'negative'],
#  [False, 3060, 2.1988875000001826, 'negative'],
#  [False, 3067, 0.0, 'positive'],
#  [False, 3068, 4.0, 'negative'],
#  [False, 3069, 2.990000000000009, 'negative'],
#  [False, 3072, 0.0, 'positive'],
#  [False, 3073, 0.0, 'negative'],
#  [False, 3078, -2.1075000000000728, 'positive'],
#  [False, 3080, -0.01999999999998181, 'positive'],
#  [False, 3083, 0.0, 'positive'],
#  [False, 3088, -6.90616666666665, 'positive'],
#  [False, 3089, -5.998833333333096, 'positive'],
#  [False, 3094, 0.31950000000006185, 'negative'],
#  [False, 3095, 0.0, 'negative'],
#  [False, 3101, 0.0, 'negative'],
#  [False, 3102, 4.005000000000109, 'negative'],
#  [False, 3103, 5.889999999999873, 'negative'],
#  [False, 3104, 2.9050000000002, 'negative'],
#  [False, 3105, 2.7906749999997373, 'negative'],
#  [False, 3108, -0.5399999999999636, 'positive'],
#  [False, 3109, 35.63999999999987, 'negative'],
#  [False, 3114, 0.0, 'positive'],
#  [False, 3115, -0.279700000000048, 'positive'],
#  [False, 3116, 0.0, 'negative'],
#  [False, 3118, -4.414999999999964, 'positive'],
#  [False, 3120, 0.3700000000003456, 'negative'],
#  [False, 3123, 8.334924999999657, 'negative'],
#  [False, 3127, 2.095833333333303, 'negative'],
#  [False, 3128, 0.31666666666660603, 'negative'],
#  [False, 3129, 0.0, 'negative'],
#  [False, 3132, -26.615714285714603, 'positive'],
#  [False, 3133, 0.0, 'negative'],
#  [False, 3135, 9.039999999999964, 'negative'],
#  [False, 3136, 1.449999999999818, 'negative'],
#  [False, 3141, 1.3096999999997934, 'negative'],
#  [False, 3145, -0.6567666666664991, 'positive'],
#  [False, 3146, 0.6100999999998749, 'negative'],
#  [False, 3147, 18.34963999999991, 'negative'],
#  [False, 3148, -3.8596400000001267, 'positive'],
#  [False, 3155, 0.7600000000002183, 'negative'],
#  [False, 3156, -2.5900000000001455, 'positive'],
#  [False, 3161, 12.941666666666606, 'negative'],
#  [False, 3164, 0.0, 'positive'],
#  [False, 3166, 0.0, 'positive'],
#  [False, 3167, -3.292399999999816, 'positive'],
#  [False, 3168, 16.795000000000073, 'negative'],
#  [False, 3171, 0.18499999999994543, 'negative'],
#  [False, 3175, -7.287249999999858, 'positive'],
#  [False, 3177, -4.301524999999856, 'positive'],
#  [False, 3180, -0.09499999999979991, 'positive'],
#  [False, 3182, -8.469974999999977, 'positive'],
#  [False, 3185, -23.85857142857185, 'positive'],
#  [False, 3187, -14.3425000000002, 'positive'],
#  [False, 3188, -8.89412857142861, 'positive'],
#  [False, 3190, -1.1446000000000822, 'positive'],
#  [False, 3193, -2.8407666666666955, 'positive'],
#  [False, 3195, 3.386273684210664, 'negative'],
#  [False, 3197, 0.0, 'positive'],
#  ...]

# %% [markdown]
# It turns out the average from the time an article is published until the next publishing article is not an accurate measure of a news. Let's focus on the ***'close' - 'open'*** in the time slot a news is published

# %%
matching_with_sentiment_diff = []
for i in range(len(publishing_indices)):
    diff = data['close'][i] - data['open'][i]
    if (diff > 0 and rob_sentiment[i] == 'positive') or (diff < 0 and rob_sentiment[i] == 'negative'):
        matching_with_sentiment_diff.append([True , i , diff , rob_sentiment[i]])
    elif rob_sentiment[i] == 'neutral':
        continue
    else:
        matching_with_sentiment_diff.append([False , i , diff , rob_sentiment[i]])
avg = sum([matching_with_sentiment_diff[i][0] == True for i in range(len(matching_with_sentiment_diff))]) / len(matching_with_sentiment_diff)
print(f'Average percentage of times the articles\' sentiment matches close - open price movement for Amazon is:\n {avg *100}')
# Out:
# Average percentage of times the articles' sentiment matches close - open price movement for Amazon is:
#  44.405099150141645

# %% [markdown]
# What if we let the news sink a bit and look at the price some 2 hours later?! We get slightly better results than flipping of a coin but still very much looks like a gamble.

# %%
matching_with_sentiment_diff = []
for i in range(len(publishing_indices)):
    diff = data['close'][i+9] - data['open'][i]
    if (diff > 0 and rob_sentiment[i] == 'positive') or (diff < 0 and rob_sentiment[i] == 'negative'):
        matching_with_sentiment_diff.append([True , i , diff , rob_sentiment[i]])
    elif rob_sentiment[i] == 'neutral':
        continue
    else:
        matching_with_sentiment_diff.append([False , i , diff , rob_sentiment[i]])
avg = sum([matching_with_sentiment_diff[i][0] == True for i in range(len(matching_with_sentiment_diff))]) / len(matching_with_sentiment_diff)
print(f'The result of waiting for a while (2 hours in this case) is {avg * 100}, slightly better!')
# Out:
# The result of waiting for a while (2 hours in this case) is 50.849858356940516

# %% [markdown]
# Let's look at Apple

# %%
data = pd.read_csv('~/Downloads/MyCourses/StockMarketSentimentAnalysis/AAPL_prerob.csv')

# Converting the stock_times into datetime objects
data['stock_time'] = pd.to_datetime(data['stock_time'])

# extracting indices of times immediately after a news article was published
publishing_indices = data[data['Publishing Time'].notna()].index

averages = []
for i in range(len(publishing_indices) + 1):
    if i == 0:
        start, end = 0 , publishing_indices[0]
    elif i == len(publishing_indices):
        start, end = publishing_indices[-1], len(data) - 1
    else:
        start, end = publishing_indices[i - 1], publishing_indices[i]
#     print(f'start is {start} end is {end}')
    averages.append(data['open'][start:end].mean())
    
rob_sentiment = data['rob_sentiment'][data['rob_sentiment'].notna()]
rob_sentiment = list(rob_sentiment)

# %%
matching_with_sentiment = []
for i in range(1 , len(averages)-1):
    diff = averages[i] - averages[i - 1]
    if (diff > 0 and rob_sentiment[i] == 'positive') or (diff < 0 and rob_sentiment[i] == 'negative'):
        matching_with_sentiment.append([True , i , diff , rob_sentiment[i]])
    elif rob_sentiment[i] == 'neutral':
        continue
    else:
        matching_with_sentiment.append([False , i , diff , rob_sentiment[i]])

avg = sum([matching_with_sentiment[i][0] == True for i in range(len(matching_with_sentiment))]) / len(matching_with_sentiment)
print(f'Average percentage of times the articles\' sentiment matched the average stock price movement is {avg *100}')
# Out:
# Average percentage of times the articles' sentiment matched the average stock price movement is 44.91823899371069

# %%
matching_with_sentiment_diff = []
for i in range(len(publishing_indices)):
    diff = data['close'][i] - data['open'][i]
    if (diff > 0 and rob_sentiment[i] == 'positive') or (diff < 0 and rob_sentiment[i] == 'negative'):
        matching_with_sentiment_diff.append([True , i , diff , rob_sentiment[i]])
    elif rob_sentiment[i] == 'neutral':
        continue
    else:
        matching_with_sentiment_diff.append([False , i , diff , rob_sentiment[i]])
open_close = sum([matching_with_sentiment_diff[i][0] == True for i in range(len(matching_with_sentiment_diff))]) / len(matching_with_sentiment_diff)
print(f'Average percentage of times the articles\' sentiment matched the stock price movement at the close relative to the opening price {open_close *100}')
# Out:
# Average percentage of times the articles' sentiment matched the stock price movement at the close relative to the opening price 46.723682555653376

# %%
matching_with_sentiment_diff = []
for i in range(len(publishing_indices)):
    diff = data['close'][i + 14] - data['open'][i]
    if (diff > 0 and rob_sentiment[i] == 'positive') or (diff < 0 and rob_sentiment[i] == 'negative'):
        matching_with_sentiment_diff.append([True , i , diff , rob_sentiment[i]])
    elif rob_sentiment[i] == 'neutral':
        continue
    else:
        matching_with_sentiment_diff.append([False , i , diff , rob_sentiment[i]])
open_close = sum([matching_with_sentiment_diff[i][0] == True for i in range(len(matching_with_sentiment_diff))]) / len(matching_with_sentiment_diff)
print(f'Average percentage of times the articles\' sentiment matched the stock price movement at the close some three hours after the publishing of the article relative to the opening price {open_close *100}')
# Out:
# Average percentage of times the articles' sentiment matched the stock price movement at the close some three hours after the publishing of the article relative to the opening price 50.106904791850084

# %% [markdown]
# ### The news sentiment was more correlated with the price change of a less-known stock as in Eli Lilly

# %%
data = pd.read_csv('~/Downloads/MyCourses/StockMarketSentimentAnalysis/LLY_prerob.csv')

# Converting the stock_times into datetime objects
data['stock_time'] = pd.to_datetime(data['stock_time'])

# extracting indices of times immediately after a news article was published
publishing_indices = data[data['Publishing Time'].notna()].index

averages = []
for i in range(len(publishing_indices) + 1):
    if i == 0:
        start, end = 0 , publishing_indices[0]
    elif i == len(publishing_indices):
        start, end = publishing_indices[-1], len(data) - 1
    else:
        start, end = publishing_indices[i - 1], publishing_indices[i]
#     print(f'start is {start} end is {end}')
    averages.append(data['open'][start:end].mean())
    
rob_sentiment = data['rob_sentiment'][data['rob_sentiment'].notna()]
rob_sentiment = list(rob_sentiment)

# %%
matching_with_sentiment = []
for i in range(1 , len(averages)-1):
    diff = averages[i] - averages[i - 1]
    if (diff > 0 and rob_sentiment[i] == 'positive') or (diff < 0 and rob_sentiment[i] == 'negative'):
        matching_with_sentiment.append([True , i , diff , rob_sentiment[i]])
    elif rob_sentiment[i] == 'neutral':
        continue
    else:
        matching_with_sentiment.append([False , i , diff , rob_sentiment[i]])

avg = sum([matching_with_sentiment[i][0] == True for i in range(len(matching_with_sentiment))]) / len(matching_with_sentiment)
print(f'Average percentage of times the articles\' sentiment matched the average stock price movement is {avg *100}')
# Out:
# Average percentage of times the articles' sentiment matched the average stock price movement is 54.9717057396928

# %%
data = pd.read_csv('~/Downloads/MyCourses/StockMarketSentimentAnalysis/news_openai_final.csv')
data.head()
# Out:
#              Publishing Time Ticker      Sector           Source  \
# 0  2019-03-15 10:46:42+00:00    WFC     Finance  The Motley Fool
# 1  2019-03-15 10:47:26+00:00   AAPL  Technology  The Motley Fool
# 2  2019-03-15 11:33:00+00:00     MA     Finance           Forbes
# 3  2019-03-15 11:52:45+00:00    BAC     Finance         Benzinga
# 4  2019-03-15 13:29:39+00:00  GOOGL  Technology         Benzinga
#
#                                             Headline  \
# 0  Did Wells Fargo CEO Tim Sloan Earn His $1 Mill...
# 1        Don't Underestimate Apple's iPhone Business
# 2    A Closer Look At Mastercard's Key Value Drivers
# 3  Jim Cramer Gives His Opinion On Bank Of Americ...
# 4  Uber And Waymo Seeking Outside Funding For Aut...
#
#                                                 Text  openai_sentiment  \
# 0  We learned this week that the scandal-plagued ...              -1.0
# 1  The segment is an invaluable asset to Apple's ...               1.0
# 2  Mastercard has consistently beat street estima...               1.0
# 3  On CNBC's "Mad Money Lightning Round", Jim Cra...               1.0
# 4  Commercially viable autonomous vehicle (AV) te...               0.0
#
#    openai_score
# 0         -0.50
# 1          0.75
# 2          0.80
# 3          0.50
# 4          0.10
